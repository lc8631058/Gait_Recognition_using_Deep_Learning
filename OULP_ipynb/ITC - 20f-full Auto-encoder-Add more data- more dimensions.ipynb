# %% [markdown]
# # Convolutional Autoencoder
#
# Sticking with the MNIST dataset, let's improve our autoencoder's performance using convolutional layers. Again, loading modules and the data.

# %%
# %matplotlib inline

import numpy as np
import tensorflow as tf 
import matplotlib.pyplot as plt
import os 
import matplotlib.pyplot as plt
from matplotlib.image import imread
from sklearn.utils import shuffle
from scipy.misc import imsave
from scipy.misc import imresize
import numpy as np
from numpy import genfromtxt
import tensorflow as tf
from PIL import Image
import pickle
# from tensorflow_vgg import vgg16|
import collections
import time
import math

# %% [markdown]
# # Import GEI dataset

# %%
img = imread('{}'.format(os.path.join('./OULP-C1V2_Pack/OULP-GEI-(88x128)-10f/Seq00/0000024', '0000024_55_GEI_10f.png')))
# img = imresize(img, [64, 64], interp='nearest')
print(img.shape)
plt.imshow(img)
plt.show()
# Out:
# (128, 88)

# %%
# Create Training Data
path = './OULP-C1V2_Pack/OULP-GEI-(88x128)-5f_5/Seq01'
Seq_10f_list = os.listdir(path)
# Seq_10f_list.remove('.DS_Store')

Seq = []
for each_seq in Seq_10f_list:
    seq_path = os.path.join(path, each_seq)
    GEI = []
    for each_GEI in os.listdir(seq_path):
        img = imread('{}'.format(os.path.join(seq_path, each_GEI)))
        img = imresize(img, [64, 64], interp='nearest')
        GEI.append(img)
    Seq.append(np.array(GEI))
Seq = np.array(Seq)
Seq1 = np.ndarray([len(Seq),4,64,64], dtype=float)
for ii, each in enumerate(Seq):
    Seq1[ii] = each

# %%
with open('../gait_data/OULP_GEI/GEI64x64_5f_5_Seq01', 'wb') as f:
    np.save(f, Seq1)

# %% [markdown]
# # Checkpoint 1

# %%
gallery_20f = np.load(open(r'../gait_data/OULP_GEI/GEI64x64_20f_Seq00', mode='rb'))
probe_20f = np.load(open(r'../gait_data/OULP_GEI/GEI64x64_20f_Seq01', mode='rb'))
gallery_full = np.load(open(r'../gait_data/OULP_GEI/GEI64x64_full_Seq00', mode='rb'))
probe_full = np.load(open(r'../gait_data/OULP_GEI/GEI64x64_full_Seq01', mode='rb'))

gallery_20f_2 = np.load(open(r'../gait_data/OULP_GEI/GEI64x64_20f_2_Seq00', mode='rb'))
probe_20f_2 = np.load(open(r'../gait_data/OULP_GEI/GEI64x64_20f_2_Seq01', mode='rb'))

gallery_20f_3 = np.load(open(r'../gait_data/OULP_GEI/GEI64x64_20f_3_Seq00', mode='rb'))
probe_20f_3 = np.load(open(r'../gait_data/OULP_GEI/GEI64x64_20f_3_Seq01', mode='rb'))

gallery_20f_4 = np.load(open(r'../gait_data/OULP_GEI/GEI64x64_20f_4_Seq00', mode='rb'))
probe_20f_4 = np.load(open(r'../gait_data/OULP_GEI/GEI64x64_20f_4_Seq01', mode='rb'))

gallery_20f_5 = np.load(open(r'../gait_data/OULP_GEI/GEI64x64_20f_5_Seq00', mode='rb'))
probe_20f_5 = np.load(open(r'../gait_data/OULP_GEI/GEI64x64_20f_5_Seq01', mode='rb'))

gallery_20f_6 = np.load(open(r'../gait_data/OULP_GEI/GEI64x64_20f_6_Seq00', mode='rb'))
probe_20f_6 = np.load(open(r'../gait_data/OULP_GEI/GEI64x64_20f_6_Seq01', mode='rb'))

# %%
gallery_20f = gallery_20f/float(255)
probe_20f = probe_20f/float(255)
gallery_full = gallery_full/float(255)
probe_full = probe_full/float(255)

gallery_20f_2 = gallery_20f_2/float(255)
probe_20f_2 = probe_20f_2/float(255)

gallery_20f_3 = gallery_20f_3/float(255)
probe_20f_3 = probe_20f_3/float(255)

gallery_20f_4 = gallery_20f_4/float(255)
probe_20f_4 = probe_20f_4/float(255)

gallery_20f_5 = gallery_20f_5/float(255)
probe_20f_5 = probe_20f_5/float(255)

gallery_20f_6 = gallery_20f_6/float(255)
probe_20f_6 = probe_20f_6/float(255)

# %% [markdown]
# <br><br><br><br><br><br><br><br><br>

# %%
# Train X
train_x = np.concatenate([gallery_20f[:2146, 3], probe_20f[:2146, 3], gallery_20f_2[:2146, 3], 
                          probe_20f_2[:2146, 3], gallery_20f_3[:2146, 3], probe_20f_3[:2146, 3],
                          gallery_20f_4[:2146, 3], probe_20f_4[:2146, 3], gallery_20f_5[:2146, 3], 
                          probe_20f_5[:2146, 3], gallery_20f_6[:2146, 3], probe_20f_6[:2146, 3]], axis=0)
train_x = np.reshape(train_x, [train_x.shape[0], train_x.shape[1], train_x.shape[2], 1])
# Train Y
train_y = np.concatenate([gallery_full[:2146, 3], probe_full[:2146, 3], gallery_full[:2146, 3], 
                          probe_full[:2146, 3], gallery_full[:2146, 3], probe_full[:2146, 3],
                          gallery_full[:2146, 3], probe_full[:2146, 3], gallery_full[:2146, 3], 
                          probe_full[:2146, 3], gallery_full[:2146, 3], probe_full[:2146, 3]], axis=0)
train_y = np.reshape(train_y, [train_y.shape[0], train_y.shape[1], train_y.shape[2], 1])
print('train_x', train_x.shape, 'train_y', train_y.shape)

# Val X
val_x = np.concatenate([gallery_20f[2146:2646, 3], gallery_20f_2[2146:2646, 3], gallery_20f_3[2146:2646, 3],
                        gallery_20f_4[2146:2646, 3], gallery_20f_5[2146:2646, 3], gallery_20f_6[2146:2646, 3],
                        probe_20f[2146:2646, 3], probe_20f_2[2146:2646, 3], probe_20f_3[2146:2646, 3], 
                        probe_20f_4[2146:2646, 3], probe_20f_5[2146:2646, 3], probe_20f_6[2146:2646, 3]], axis=0)
val_x = np.reshape(val_x, [val_x.shape[0], val_x.shape[1], val_x.shape[2], 1])
# Val Y
val_y = np.concatenate([gallery_full[2146:2646, 3], gallery_full[2146:2646, 3], gallery_full[2146:2646, 3], 
                        gallery_full[2146:2646, 3], gallery_full[2146:2646, 3], gallery_full[2146:2646, 3], 
                        probe_full[2146:2646, 3], probe_full[2146:2646, 3], probe_full[2146:2646, 3], 
                        probe_full[2146:2646, 3], probe_full[2146:2646, 3], probe_full[2146:2646, 3]], axis=0)
val_y = np.reshape(val_y, [val_y.shape[0], val_y.shape[1], val_y.shape[2], 1])
print('val_x', val_x.shape, 'val_y', val_y.shape)

# Test X
test_x = np.concatenate([gallery_20f[2646:, 3], gallery_20f_2[2646:, 3], gallery_20f_3[2646:, 3],
                         gallery_20f_4[2646:, 3], gallery_20f_5[2646:, 3], gallery_20f_6[2646:, 3], 
                         probe_20f[2646:, 3], probe_20f_2[2646:, 3], probe_20f_3[2646:, 3],
                         probe_20f_4[2646:, 3], probe_20f_5[2646:, 3], probe_20f_6[2646:, 3]], 
                        axis=0)
test_x = np.reshape(test_x, [test_x.shape[0], test_x.shape[1], test_x.shape[2], 1])
# Test Y
test_y = np.concatenate([gallery_full[2646:, 3], gallery_full[2646:, 3], gallery_full[2646:, 3], 
                         gallery_full[2646:, 3], gallery_full[2646:, 3], gallery_full[2646:, 3], 
                         probe_full[2646:, 3], probe_full[2646:, 3], probe_full[2646:, 3], probe_full[2646:, 3], 
                         probe_full[2646:, 3], probe_full[2646:, 3]], axis=0)
test_y = np.reshape(test_y, [test_y.shape[0], test_y.shape[1], test_y.shape[2], 1])
print('test_x', test_x.shape, 'test_y', test_y.shape)
# Out:
# train_x (25752, 64, 64, 1) train_y (25752, 64, 64, 1)
# val_x (6000, 64, 64, 1) val_y (6000, 64, 64, 1)
# test_x (6000, 64, 64, 1) test_y (6000, 64, 64, 1)

# %% [markdown]
# # Create Graph

# %%
def build_inputs_outputs():
    inputs_1 = tf.placeholder(tf.float32, (None, 64, 64, 1), name='inputs_1')
    targets_1 = tf.placeholder(tf.float32, (None, 64, 64, 1), name='targets_1')
    
    return inputs_1, targets_1

def conv_layer(inputs_, weights_name, bias_name, conv_name, pool_name, bn_name, relu_name, add_bacth_norm=True, is_training=True, 
               set_stddev=0.03, out_dim=1, conv_kernsize=(2,2), conv_strides=(1,1), pool_size=(2,2), pool_strides=(2,2), 
               keep_prob=0.5):
    ### Encoder
    # e.g. out_dim: 8; kern_size: (3,3); pool_size: (2,2); strides: (2,2);
        
    # filter:[filter_height, filter_width, in_channels, out_channels]
    weight = tf.Variable(tf.truncated_normal([conv_kernsize[0],conv_kernsize[1],\
                         inputs_.get_shape().as_list()[3], out_dim], stddev=set_stddev),\
                         name=weights_name) 
    
    # Set bias
    bias = tf.Variable(tf.zeros(out_dim), name=bias_name)
    
    # set strides of conv2d
    stride = [1, conv_strides[0], conv_strides[1], 1]
    
    # conv2d
    # input:[batch, in_height, in_width, in_channels]
    conv2d = tf.nn.bias_add(tf.nn.conv2d(inputs_, weight, stride, padding='SAME', name=conv_name), bias)
    
    # add activation function
    conv2d = tf.nn.relu(conv2d, name=relu_name)
    
    # add Max pooling
    conv2d = tf.nn.max_pool(conv2d, [1,pool_size[0],pool_size[1],1],\
                                    [1,pool_strides[0],pool_strides[1],1], padding='SAME', name=pool_name)   
    # Now 28x28x
    if add_bacth_norm:
        conv2d = tf.layers.batch_normalization(conv2d, training=is_training, name=bn_name)
        
    conv2d_maxpool = tf.layers.dropout(conv2d, rate=keep_prob)
        
    return conv2d_maxpool

#     # Now 14x14x16
#     conv2 = tf.layers.conv2d(maxpool1, 8, (3,3), padding='same', activation=tf.nn.relu)
#     # Now 14x14x8
#     maxpool2 = tf.layers.max_pooling2d(conv2, (2,2), (2,2), padding='same')
#     # Now 7x7x8
#     conv3 = tf.layers.conv2d(maxpool2, 8, (3,3), padding='same', activation=tf.nn.relu)
#     # Now 7x7x8
#     encoded = tf.layers.max_pooling2d(conv3, (2,2), (2,2), padding='same')
#     # Now 4x4x8

def deconv_layer(encoded, up_name, weights_name, bias_name, de_conv_name, bn_name, relu_name, add_batch_norm=True, is_training=True, 
                 set_stddev=0.03, up_size=[(2,2),(4,4),(5,5),(6,6)], out_dim=1, conv_kernsize=(2,2), conv_strides=(1,1), keep_prob=0.5):
    ### Decoder
    upsample = tf.image.resize_nearest_neighbor(encoded, up_size, name=up_name) # up_size: e.g.(7,7)
    
    # set weight (filter)
    weight = tf.Variable(tf.truncated_normal([conv_kernsize[0],conv_kernsize[1],\
                         upsample.get_shape().as_list()[3], out_dim], stddev=set_stddev),\
                         name=weights_name)
    
    # set bias
    bias = tf.Variable(tf.zeros(out_dim), name=bias_name)
    
    # set strides of conv2d
    stride = [1, conv_strides[0], conv_strides[1], 1]
    
    # conv2d
    conv2d = tf.nn.bias_add(tf.nn.conv2d(upsample, weight, stride, padding='SAME', name=de_conv_name),\
                   bias)
    
    conv2d = tf.nn.relu(conv2d, name=relu_name)
    
    if add_batch_norm:
        conv2d = tf.layers.batch_normalization(conv2d, training=is_training, name=bn_name)
    
    conv2d = tf.layers.dropout(conv2d, rate=keep_prob)
    
    return conv2d

#     # Now 7x7x8
#     upsample2 = tf.image.resize_nearest_neighbor(conv4, (14,14))
#     # Now 14x14x8
#     conv5 = tf.layers.conv2d(upsample2, 8, (3,3), padding='same', activation=tf.nn.relu)
#     # Now 14x14x8
#     upsample3 = tf.image.resize_nearest_neighbor(conv5, (28,28))
#     # Now 28x28x8
#     conv6 = tf.layers.conv2d(upsample3, 16, (3,3), padding='same', activation=tf.nn.relu)
#     # Now 28x28x16

def output_layer(conv2d, weights_name, bias_name, logits_name, bn_name, decoded_name, add_batch_norm=True, is_training=True, 
                 set_stddev=0.03, out_dim=1, conv_kernsize=(3,3), conv_strides=(1,1)):
    # set weight (filter)
    weight = tf.Variable(tf.truncated_normal([conv_kernsize[0],conv_kernsize[1],\
                         conv2d.get_shape().as_list()[3], out_dim], stddev=set_stddev),\
                         name=weights_name)
    
    # set bias
    bias = tf.Variable(tf.zeros(out_dim), name=bias_name)
    
    # set strides of conv2d
    stride = [1, conv_strides[0], conv_strides[1], 1]
    
    # conv2d
    logits = tf.nn.bias_add(tf.nn.conv2d(conv2d, weight, stride, padding='SAME', name=logits_name),\
                   bias)
    
    if add_batch_norm:
        conv2d = tf.layers.batch_normalization(conv2d, training=is_training, name=bn_name)
    #Now 28x28x1
    decoded = tf.nn.sigmoid(logits, name=decoded_name)
    
    return logits, decoded

# %%
def build_graph(kern_size, std, conv_strides, pool_size, pool_strides, de_kern_size, 
                de_conv_strides, out_kern_size, out_strides, up_size=[(16,16), (32,32), (64,64)]):
    
    # reset graph
    tf.reset_default_graph()
    
    with tf.name_scope('inputs_targets'):
        inputs_1, targets_1 = build_inputs_outputs()
    
    keep_p = tf.placeholder(tf.float32, name="keep_prob")
    
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    
    training = tf.placeholder(tf.bool, name='training')
    
    with tf.name_scope('conv_layers'):
        
        maxpool_1 = conv_layer(inputs_1, 'conv_weights_1', 'bias_1', 'conv_1', 'pool_1', 'bn_1', 'relu_1', add_bacth_norm=False, 
                               is_training=training, set_stddev=std, out_dim=128, conv_kernsize=kern_size, conv_strides=conv_strides, 
                               pool_size=pool_size, pool_strides=pool_strides, keep_prob=keep_p)
        
        maxpool_2 = conv_layer(maxpool_1, 'conv_weights_2', 'bias_2', 'conv_2', 'pool_2', 'bn_2', 'relu_2', add_bacth_norm=True, 
                               is_training=training, set_stddev=std, out_dim=64, conv_kernsize=kern_size, conv_strides=conv_strides, 
                               pool_size=pool_size, pool_strides=pool_strides, keep_prob=keep_p)
        
        maxpool_3 = conv_layer(maxpool_2, 'conv_weights_3', 'bias_3', 'conv_3', 'pool_3', 'bn_3', 'relu_3', add_bacth_norm=True, 
                               is_training=training, set_stddev=std, out_dim=32, conv_kernsize=kern_size, conv_strides=conv_strides, 
                               pool_size=pool_size, pool_strides=pool_strides, keep_prob=keep_p)
        
#         maxpool_4 = conv_layer(maxpool_3, 'conv_weights_4', 'bias_4', 'conv_4', 'pool_4', 'bn_4', 'relu_4', add_bacth_norm=True, 
#                                is_training=training, set_stddev=std, out_dim=8, conv_kernsize=kern_size, conv_strides=conv_strides, 
#                                pool_size=pool_size, pool_strides=pool_strides, keep_prob=keep_p)
        # Now 4x4x8 as hidden layer
        
    with tf.name_scope('deconv_layers'):
        
        deconv_1 = deconv_layer(maxpool_3, 'up_1', 'deconv_weights_1', 'debias_1', 'deconv_1', 'de_bn_1', 'de_relu_1', add_batch_norm=True, 
                              is_training=training, set_stddev=std, up_size=up_size[0], out_dim=32, conv_kernsize=de_kern_size,
                              conv_strides=de_conv_strides, keep_prob=keep_p)
        
        deconv_2 = deconv_layer(deconv_1, 'up_2', 'deconv_weights_2', 'debias_2', 'deconv_2', 'de_bn_2', 'de_relu_2', add_batch_norm=True, 
                              is_training=training, set_stddev=std, up_size=up_size[1], out_dim=64, conv_kernsize=de_kern_size,
                              conv_strides=de_conv_strides, keep_prob=keep_p)
        
        deconv_3 = deconv_layer(deconv_2, 'up_3', 'deconv_weights_3', 'debias_3', 'deconv_3', 'de_bn_3', 'de_relu_3', add_batch_norm=True, 
                              is_training=training, set_stddev=std, up_size=up_size[2], out_dim=128, conv_kernsize=de_kern_size,
                              conv_strides=de_conv_strides, keep_prob=keep_p)
        
#         deconv_4 = deconv_layer(deconv_3, 'up_4', 'deconv_weights_4', 'debias_4', 'deconv_4', 'de_bn_4', 'de_relu_4', add_batch_norm=True, 
#                               is_training=training, set_stddev=std, up_size=up_size[3], out_dim=64, conv_kernsize=de_kern_size,
#                               conv_strides=de_conv_strides, keep_prob=keep_p)
        
    with tf.name_scope('output_layer'):
       
        logits, decoded = output_layer(deconv_3, 'output_weights', 'outbias_1', 'logits', 'bn', 'decoded', add_batch_norm=False, is_training=training, 
                                       set_stddev=std, out_dim=1, conv_kernsize=out_kern_size, conv_strides=out_strides)
    
    MSE = tf.reduce_mean(tf.losses.mean_squared_error(targets_1, decoded), name='MSE')
    loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=targets_1, logits=logits, name='loss')
    cost = tf.reduce_mean(loss, name='cost')
#     cost = tf.losses.mean_squared_error(targets_1, decoded)
    opt = tf.train.AdamOptimizer(learning_rate).minimize(MSE)
    
    with tf.name_scope('saver'):
        saver = tf.train.Saver()
        
#     merged = tf.summary.merge_all()
    
    export_nodes = ['inputs_1', 'targets_1', 'maxpool_1', 'maxpool_2', 'maxpool_3', 'deconv_1', 'deconv_2', 
                    'deconv_3', 'training', 'logits', 'decoded', 'loss', 'cost', 'opt', 'saver', 'learning_rate', 'keep_p', 'MSE']
    
    Graph = collections.namedtuple('Graph', export_nodes)
    local_dict = locals()
    graph = Graph(*[local_dict[each] for each in export_nodes])
    
    return graph

# %%
def get_batches(data, target, batch_size):
    n_batches = len(data)//batch_size
    data = data[:batch_size * n_batches]
    target = target[:batch_size * n_batches]
    for ii in range(0, batch_size*n_batches, batch_size):
        data_batch = data[ii:ii + batch_size]
        target_batch = target[ii:ii + batch_size]
        
        yield data_batch, target_batch
        
        
def cal_accuracy(decoded, target):
    error = abs(decoded - target)
    Acc = (np.sum(error <= 0.08)/(decoded.shape[0]*decoded.shape[1]*decoded.shape[2]*decoded.shape[3]))*100
    
    return Acc

# %%
def train(model, epochs, save_string):

    with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
        sess.run(tf.global_variables_initializer())
        
        iteration = 1
        mean_val_loss = 0
        mean_val_mse = 0
        mean_val_acc = 0
        count_loss_not_decrease_epochs = 0
        count_acc_not_decrease_epochs = 0
        Last_val_loss = 0
        Last_val_mse = 0
        Last_val_acc = 0
        
        
        for e in range(epochs):
            for train_batch, target_batch in get_batches(train_x, train_y, batch_size):
                    
                start = time.time()
                
                feed_1 = {
                        model.inputs_1: train_batch, 
                        model.targets_1: target_batch,
                        model.keep_p: 0.5,
                        model.learning_rate: lr,
                        model.training:True
                        }

                train_loss, _, decoded_img, train_mse = sess.run([model.cost, model.opt, model.decoded, model.MSE], feed_dict=feed_1)
                
                train_acc = cal_accuracy(decoded_img, target_batch)
                
                if iteration%25==0:
                    end = time.time()
#                     acc = calculate_accuracy(sess, pred, target_batch, sq_length)
                    print("Epoch: {}/{},".format(e+1, epochs),' '
                          "Iteration: {},".format(iteration),' '
                          "Train loss: {:.3f},".format(train_loss),' '
                          "Train MSE: {:.4f},".format(train_mse * 65025),' '
                          "{:.1f}s /batch.".format((end-start)/5),' '
                          "Train Accuracy: %{:.3f}".format(train_acc))

                ##############################################################
                ######################## VALIDATION ##########################
                ##############################################################
                
                if iteration%75==0:
#                     training = True
                    validation_loss = []
                    validation_mse = []
                    validation_acc = []
                    
                    if batch_size >= len(val_x):
                        val_batch_size = len(val_x)
                    else: 
                        val_batch_size = batch_size
                        

                    for ii, (val_batch, val_target_batch) in enumerate(get_batches(val_x, val_y, val_batch_size)):
#                         print(ii, len(val_x)//val_batch_size)
                        feed_2 = {
                                model.inputs_1: val_batch,
                                model.targets_1: val_target_batch,
                                model.keep_p: 1,
                                model.training:True
                                }
                        
                        val_loss, val_decoded_img, val_mse = sess.run([model.cost, model.decoded, model.MSE], 
                                                                          feed_dict=feed_2)

                        val_acc = cal_accuracy(val_decoded_img, val_target_batch)
                        
                        validation_loss.append(val_loss)
                        validation_mse.append(val_mse)
                        validation_acc.append(val_acc)
                    
                    Last_val_loss = mean_val_loss
                    Last_val_mse = mean_val_mse
                    Last_val_acc = mean_val_acc
                    mean_val_loss = np.mean(np.array(validation_loss))
                    mean_val_mse = np.mean(np.array(validation_mse))
                    mean_val_acc = np.mean(np.array(validation_acc))
                    
                    print()
                    print("Validation loss: {:.3f},".format(mean_val_loss),' '
                          "Validation mse: {:.4f},".format(mean_val_mse * 65025),' '
                          "Validation accuracy: %{:.3f},".format(mean_val_acc))
#                           "maxpool_3.shape: {}.".format(max_pool_3[0].shape))
                    print()
                ####### plot #######
#                 if iteration%500==0:
                    
#                     feed_3 = {
#                             model.inputs_1: val_x[:10],
#                             model.keep_p: 1,
#                             model.training:True
#                             }
                    
#                     fig, axes = plt.subplots(nrows=3, ncols=10, sharex=True, sharey=True, figsize=(20,4))
#                     in_imgs = val_x[:10]
#                     target_imgs = val_y[:10]
#                     reconstructed = sess.run(model.decoded, feed_dict=feed_3)

##                     plot out
#                     for images, row in zip([in_imgs, target_imgs, reconstructed], axes):
#                         for img, ax in zip(images, row):
#                             ax.imshow(img.reshape((64, 64)), cmap='Greys_r')
#                             ax.get_xaxis().set_visible(False)
#                             ax.get_yaxis().set_visible(False)


#                     fig.tight_layout(pad=0.1)
                            
                    
                    
                    
                    
                iteration += 1
                
            # Early stopping :
            if mean_val_acc > 96.2:
                break
#             if mean_val_Acc - Last_val_Acc <= -0.3:
#                 count_Acc_not_increase_epochs += 1
#             if Last_val_loss - mean_val_loss <= -0.01:
#                 count_loss_not_decrease_epochs += 1
                
#             if mean_val_Acc - Last_val_Acc <= -2:
#                 break
#             if count_Acc_not_increase_epochs >= 10:
#                 break
#             if count_loss_not_decrease_epochs >= 10:
#                 break
                
        model.saver.save(sess, r"{}".format(save_string))

# %%
train_x, train_y = shuffle(train_x, train_y)
val_x, val_y = shuffle(val_x, val_y)

# %%
# !mkdir checkpoints_view_invariant

dimension = 128
epochs = 3000
num_layers = 3
batch_size = 80
conv_kern_size = (4,4) #
conv_strides = (1,1) ##
pool_size = (2,2)
pool_strides = (2,2)
# up_size = [(8,8), (16,16), (32,32), (64,64)]
up_size = [(16,16), (32,32), (64,64)]
# up_size = [(32,32), (64,64)]
de_kern_size = (4,4) #
de_conv_strides = (1,1) ##
out_kern_size = (4,4) #
out_strides = (1,1)
std = 0.02

for lr in [0.0002]:
#                 log_string = 'logs/4/lr={},nl={},ls={},bs={}'.format(lr, num_layers, lstm_size, batch_size)
    save_string = './checkpoints_view_invariant/20tofull_add-more-data_lr={}_nl={}_bs={}_dim={}.ckpt'.format(
                                                                            lr, num_layers, batch_size, dimension)
                
#             writer to_frame= tf.summary.FileWriter(log_string)
#     build_graph(kern_size, std, conv_strides, pool_size, pool_strides, de_kern_size, 
#                 de_conv_strides, out_kern_size, out_strides, up_size=[(16,16), (32,32), (64,64)], set_is_training=True):
    
    model = build_graph(conv_kern_size, std, conv_strides, pool_size, pool_strides, de_kern_size, de_conv_strides,
                        out_kern_size, out_strides, up_size=up_size)

    train(model, epochs, save_string)
                
    print(' ')
    print(' ')
    print("leraning_rate={},num_layers={},batch_size={} finished, saved".format(lr, num_layers, batch_size))
    print(' ')
    print(' ')
# Out:
# 子目录或文件 checkpoints_view_invariant 已经存在。
# Epoch: 1/3000,  Iteration: 25,  Train loss: 0.271,  Train MSE: 819.2924,  0.1s /batch.  Train Accuracy: %71.855
# Epoch: 1/3000,  Iteration: 50,  Train loss: 0.228,  Train MSE: 432.9519,  0.1s /batch.  Train Accuracy: %82.876
# Epoch: 1/3000,  Iteration: 75,  Train loss: 0.215,  Train MSE: 303.5679,  0.1s /batch.  Train Accuracy: %86.515
#
# Validation loss: 0.215,  Validation mse: 302.9761,  Validation accuracy: %86.637,
#
# Epoch: 1/3000,  Iteration: 100,  Train loss: 0.211,  Train MSE: 248.1035,  0.1s /batch.  Train Accuracy: %88.639
# Epoch: 1/3000,  Iteration: 125,  Train loss: 0.208,  Train MSE: 220.7704,  0.1s /batch.  Train Accuracy: %89.326
# Epoch: 1/3000,  Iteration: 150,  Train loss: 0.204,  Train MSE: 193.5476,  0.1s /batch.  Train Accuracy: %90.176
#
# Validation loss: 0.204,  Validation mse: 226.5103,  Validation accuracy: %88.936,
#
# Epoch: 1/3000,  Iteration: 175,  Train loss: 0.203,  Train MSE: 198.0940,  0.1s /batch.  Train Accuracy: %89.487
# Epoch: 1/3000,  Iteration: 200,  Train loss: 0.198,  Train MSE: 169.6464,  0.1s /batch.  Train Accuracy: %90.648
# Epoch: 1/3000,  Iteration: 225,  Train loss: 0.201,  Train MSE: 166.6345,  0.1s /batch.  Train Accuracy: %90.836
#
# Validation loss: 0.198,  Validation mse: 164.9864,  Validation accuracy: %91.273,
#
# Epoch: 1/3000,  Iteration: 250,  Train loss: 0.198,  Train MSE: 166.3177,  0.1s /batch.  Train Accuracy: %91.456
# Epoch: 1/3000,  Iteration: 275,  Train loss: 0.199,  Train MSE: 150.5313,  0.1s /batch.  Train Accuracy: %91.915
# Epoch: 1/3000,  Iteration: 300,  Train loss: 0.193,  Train MSE: 151.1059,  0.1s /batch.  Train Accuracy: %92.027
#
# Validation loss: 0.195,  Validation mse: 156.8785,  Validation accuracy: %91.302,
#
# Epoch: 2/3000,  Iteration: 325,  Train loss: 0.197,  Train MSE: 144.7351,  0.1s /batch.  Train Accuracy: %91.983
# Epoch: 2/3000,  Iteration: 350,  Train loss: 0.198,  Train MSE: 140.6612,  0.1s /batch.  Train Accuracy: %92.221
# Epoch: 2/3000,  Iteration: 375,  Train loss: 0.195,  Train MSE: 119.2275,  0.1s /batch.  Train Accuracy: %93.238
#
# Validation loss: 0.194,  Validation mse: 138.5751,  Validation accuracy: %92.452,
#
# Epoch: 2/3000,  Iteration: 400,  Train loss: 0.195,  Train MSE: 142.2765,  0.1s /batch.  Train Accuracy: %91.578
# Epoch: 2/3000,  Iteration: 425,  Train loss: 0.190,  Train MSE: 119.7197,  0.1s /batch.  Train Accuracy: %93.362
# Epoch: 2/3000,  Iteration: 450,  Train loss: 0.194,  Train MSE: 120.3832,  0.1s /batch.  Train Accuracy: %92.983
#
# Validation loss: 0.192,  Validation mse: 130.1702,  Validation accuracy: %92.735,
#
# Epoch: 2/3000,  Iteration: 475,  Train loss: 0.200,  Train MSE: 150.2856,  0.1s /batch.  Train Accuracy: %90.251
# Epoch: 2/3000,  Iteration: 500,  Train loss: 0.194,  Train MSE: 125.2150,  0.1s /batch.  Train Accuracy: %92.843
# Epoch: 2/3000,  Iteration: 525,  Train loss: 0.195,  Train MSE: 118.5100,  0.1s /batch.  Train Accuracy: %93.102
#
# Validation loss: 0.192,  Validation mse: 143.2731,  Validation accuracy: %92.632,
#
# Epoch: 2/3000,  Iteration: 550,  Train loss: 0.189,  Train MSE: 129.9447,  0.1s /batch.  Train Accuracy: %92.200
# Epoch: 2/3000,  Iteration: 575,  Train loss: 0.195,  Train MSE: 116.4204,  0.1s /batch.  Train Accuracy: %93.209
# Epoch: 2/3000,  Iteration: 600,  Train loss: 0.193,  Train MSE: 107.1852,  0.1s /batch.  Train Accuracy: %93.537
#
# Validation loss: 0.191,  Validation mse: 124.2199,  Validation accuracy: %92.710,
#
# Epoch: 2/3000,  Iteration: 625,  Train loss: 0.195,  Train MSE: 126.5461,  0.1s /batch.  Train Accuracy: %92.216
# Epoch: 3/3000,  Iteration: 650,  Train loss: 0.192,  Train MSE: 101.8679,  0.1s /batch.  Train Accuracy: %94.129
# Epoch: 3/3000,  Iteration: 675,  Train loss: 0.190,  Train MSE: 109.3653,  0.1s /batch.  Train Accuracy: %93.364
#
# Validation loss: 0.190,  Validation mse: 122.2843,  Validation accuracy: %93.192,
#
# Epoch: 3/3000,  Iteration: 700,  Train loss: 0.191,  Train MSE: 105.4751,  0.1s /batch.  Train Accuracy: %93.669
# Epoch: 3/3000,  Iteration: 725,  Train loss: 0.190,  Train MSE: 109.7329,  0.1s /batch.  Train Accuracy: %93.803
# Epoch: 3/3000,  Iteration: 750,  Train loss: 0.194,  Train MSE: 102.6326,  0.1s /batch.  Train Accuracy: %93.870
#
# Validation loss: 0.190,  Validation mse: 111.9025,  Validation accuracy: %93.344,
#
# Epoch: 3/3000,  Iteration: 775,  Train loss: 0.187,  Train MSE: 99.1138,  0.1s /batch.  Train Accuracy: %94.095
# Epoch: 3/3000,  Iteration: 800,  Train loss: 0.189,  Train MSE: 109.4286,  0.1s /batch.  Train Accuracy: %93.528
# Epoch: 3/3000,  Iteration: 825,  Train loss: 0.183,  Train MSE: 95.5007,  0.1s /batch.  Train Accuracy: %94.241
#
# Validation loss: 0.189,  Validation mse: 103.8979,  Validation accuracy: %93.908,
#
# Epoch: 3/3000,  Iteration: 850,  Train loss: 0.189,  Train MSE: 97.1549,  0.1s /batch.  Train Accuracy: %94.496
# Epoch: 3/3000,  Iteration: 875,  Train loss: 0.186,  Train MSE: 99.0800,  0.1s /batch.  Train Accuracy: %94.126
# Epoch: 3/3000,  Iteration: 900,  Train loss: 0.190,  Train MSE: 101.7715,  0.1s /batch.  Train Accuracy: %94.258
#
# Validation loss: 0.189,  Validation mse: 109.3042,  Validation accuracy: %93.652,
#
# Epoch: 3/3000,  Iteration: 925,  Train loss: 0.191,  Train MSE: 97.2960,  0.1s /batch.  Train Accuracy: %94.086
# Epoch: 3/3000,  Iteration: 950,  Train loss: 0.192,  Train MSE: 93.8935,  0.1s /batch.  Train Accuracy: %94.464
# Epoch: 4/3000,  Iteration: 975,  Train loss: 0.191,  Train MSE: 104.9203,  0.1s /batch.  Train Accuracy: %93.840
#
# Validation loss: 0.188,  Validation mse: 106.2714,  Validation accuracy: %93.736,
#
# Epoch: 4/3000,  Iteration: 1000,  Train loss: 0.186,  Train MSE: 87.6423,  0.1s /batch.  Train Accuracy: %94.833
# Epoch: 4/3000,  Iteration: 1025,  Train loss: 0.186,  Train MSE: 85.0990,  0.1s /batch.  Train Accuracy: %94.934
# Epoch: 4/3000,  Iteration: 1050,  Train loss: 0.191,  Train MSE: 84.3035,  0.1s /batch.  Train Accuracy: %94.883
#
# Validation loss: 0.188,  Validation mse: 97.0025,  Validation accuracy: %94.234,
#
# Epoch: 4/3000,  Iteration: 1075,  Train loss: 0.187,  Train MSE: 90.5658,  0.1s /batch.  Train Accuracy: %94.566
# Epoch: 4/3000,  Iteration: 1100,  Train loss: 0.191,  Train MSE: 91.3595,  0.1s /batch.  Train Accuracy: %94.643
# Epoch: 4/3000,  Iteration: 1125,  Train loss: 0.189,  Train MSE: 93.6441,  0.1s /batch.  Train Accuracy: %94.407
#
# Validation loss: 0.188,  Validation mse: 105.0205,  Validation accuracy: %93.687,
#
# Epoch: 4/3000,  Iteration: 1150,  Train loss: 0.188,  Train MSE: 85.6071,  0.1s /batch.  Train Accuracy: %94.800
# Epoch: 4/3000,  Iteration: 1175,  Train loss: 0.192,  Train MSE: 100.9661,  0.1s /batch.  Train Accuracy: %93.519
# Epoch: 4/3000,  Iteration: 1200,  Train loss: 0.188,  Train MSE: 86.6565,  0.1s /batch.  Train Accuracy: %94.978
#
# Validation loss: 0.187,  Validation mse: 95.6196,  Validation accuracy: %94.327,
#
# Epoch: 4/3000,  Iteration: 1225,  Train loss: 0.187,  Train MSE: 81.9935,  0.1s /batch.  Train Accuracy: %95.032
# Epoch: 4/3000,  Iteration: 1250,  Train loss: 0.187,  Train MSE: 84.4182,  0.1s /batch.  Train Accuracy: %94.837
# Epoch: 4/3000,  Iteration: 1275,  Train loss: 0.192,  Train MSE: 91.2350,  0.1s /batch.  Train Accuracy: %94.248
#
# Validation loss: 0.187,  Validation mse: 98.5511,  Validation accuracy: %94.032,
#
# Epoch: 5/3000,  Iteration: 1300,  Train loss: 0.188,  Train MSE: 105.0018,  0.1s /batch.  Train Accuracy: %93.793
# Epoch: 5/3000,  Iteration: 1325,  Train loss: 0.186,  Train MSE: 91.4425,  0.1s /batch.  Train Accuracy: %94.416
# Epoch: 5/3000,  Iteration: 1350,  Train loss: 0.187,  Train MSE: 90.6435,  0.1s /batch.  Train Accuracy: %94.369
#
# Validation loss: 0.187,  Validation mse: 91.3202,  Validation accuracy: %94.483,
#
# Epoch: 5/3000,  Iteration: 1375,  Train loss: 0.186,  Train MSE: 83.7852,  0.1s /batch.  Train Accuracy: %95.097
# Epoch: 5/3000,  Iteration: 1400,  Train loss: 0.186,  Train MSE: 82.3904,  0.1s /batch.  Train Accuracy: %95.010
# Epoch: 5/3000,  Iteration: 1425,  Train loss: 0.190,  Train MSE: 92.7737,  0.1s /batch.  Train Accuracy: %94.313
#
# Validation loss: 0.187,  Validation mse: 96.7728,  Validation accuracy: %94.112,
#
# Epoch: 5/3000,  Iteration: 1450,  Train loss: 0.182,  Train MSE: 88.9943,  0.1s /batch.  Train Accuracy: %94.778
# Epoch: 5/3000,  Iteration: 1475,  Train loss: 0.187,  Train MSE: 79.1773,  0.1s /batch.  Train Accuracy: %95.262
# Epoch: 5/3000,  Iteration: 1500,  Train loss: 0.187,  Train MSE: 89.7197,  0.1s /batch.  Train Accuracy: %94.709
#
# Validation loss: 0.187,  Validation mse: 91.1954,  Validation accuracy: %94.510,
#
# Epoch: 5/3000,  Iteration: 1525,  Train loss: 0.193,  Train MSE: 84.7460,  0.1s /batch.  Train Accuracy: %94.858
# Epoch: 5/3000,  Iteration: 1550,  Train loss: 0.182,  Train MSE: 80.1252,  0.1s /batch.  Train Accuracy: %95.179
# Epoch: 5/3000,  Iteration: 1575,  Train loss: 0.184,  Train MSE: 80.6343,  0.1s /batch.  Train Accuracy: %95.143
#
# Validation loss: 0.187,  Validation mse: 91.3916,  Validation accuracy: %94.400,
#
# Epoch: 5/3000,  Iteration: 1600,  Train loss: 0.185,  Train MSE: 79.6982,  0.1s /batch.  Train Accuracy: %95.285
# Epoch: 6/3000,  Iteration: 1625,  Train loss: 0.187,  Train MSE: 89.2691,  0.1s /batch.  Train Accuracy: %94.615
# Epoch: 6/3000,  Iteration: 1650,  Train loss: 0.187,  Train MSE: 84.1174,  0.1s /batch.  Train Accuracy: %94.770
#
# Validation loss: 0.186,  Validation mse: 87.9136,  Validation accuracy: %94.648,
#
# Epoch: 6/3000,  Iteration: 1675,  Train loss: 0.191,  Train MSE: 81.5221,  0.1s /batch.  Train Accuracy: %94.993
# Epoch: 6/3000,  Iteration: 1700,  Train loss: 0.190,  Train MSE: 77.6397,  0.1s /batch.  Train Accuracy: %95.456
# Epoch: 6/3000,  Iteration: 1725,  Train loss: 0.185,  Train MSE: 97.0698,  0.1s /batch.  Train Accuracy: %94.018
#
# Validation loss: 0.186,  Validation mse: 91.3282,  Validation accuracy: %94.480,
#
# Epoch: 6/3000,  Iteration: 1750,  Train loss: 0.188,  Train MSE: 78.4117,  0.1s /batch.  Train Accuracy: %95.291
# Epoch: 6/3000,  Iteration: 1775,  Train loss: 0.189,  Train MSE: 80.7295,  0.1s /batch.  Train Accuracy: %95.103
# Epoch: 6/3000,  Iteration: 1800,  Train loss: 0.183,  Train MSE: 96.1017,  0.1s /batch.  Train Accuracy: %93.670
#
# Validation loss: 0.186,  Validation mse: 89.4147,  Validation accuracy: %94.445,
#
# Epoch: 6/3000,  Iteration: 1825,  Train loss: 0.187,  Train MSE: 83.3744,  0.1s /batch.  Train Accuracy: %95.010
# Epoch: 6/3000,  Iteration: 1850,  Train loss: 0.182,  Train MSE: 77.5363,  0.1s /batch.  Train Accuracy: %95.336
# Epoch: 6/3000,  Iteration: 1875,  Train loss: 0.185,  Train MSE: 83.2628,  0.1s /batch.  Train Accuracy: %95.032
#
# Validation loss: 0.186,  Validation mse: 84.2968,  Validation accuracy: %94.894,
#
# Epoch: 6/3000,  Iteration: 1900,  Train loss: 0.183,  Train MSE: 76.9866,  0.1s /batch.  Train Accuracy: %95.587
# Epoch: 6/3000,  Iteration: 1925,  Train loss: 0.185,  Train MSE: 81.0982,  0.1s /batch.  Train Accuracy: %94.968
# Epoch: 7/3000,  Iteration: 1950,  Train loss: 0.186,  Train MSE: 87.3377,  0.1s /batch.  Train Accuracy: %94.444
#
# Validation loss: 0.186,  Validation mse: 89.8197,  Validation accuracy: %94.486,
#
# Epoch: 7/3000,  Iteration: 1975,  Train loss: 0.191,  Train MSE: 77.6757,  0.1s /batch.  Train Accuracy: %95.354
# Epoch: 7/3000,  Iteration: 2000,  Train loss: 0.185,  Train MSE: 77.8103,  0.1s /batch.  Train Accuracy: %95.252
# Epoch: 7/3000,  Iteration: 2025,  Train loss: 0.184,  Train MSE: 82.9228,  0.1s /batch.  Train Accuracy: %95.016
#
# Validation loss: 0.186,  Validation mse: 88.1726,  Validation accuracy: %94.711,
#
# Epoch: 7/3000,  Iteration: 2050,  Train loss: 0.186,  Train MSE: 91.3842,  0.1s /batch.  Train Accuracy: %94.655
# Epoch: 7/3000,  Iteration: 2075,  Train loss: 0.189,  Train MSE: 83.5899,  0.1s /batch.  Train Accuracy: %94.828
# Epoch: 7/3000,  Iteration: 2100,  Train loss: 0.195,  Train MSE: 84.2156,  0.1s /batch.  Train Accuracy: %94.758
#
# Validation loss: 0.186,  Validation mse: 86.3165,  Validation accuracy: %94.862,
#
# Epoch: 7/3000,  Iteration: 2125,  Train loss: 0.187,  Train MSE: 86.5278,  0.1s /batch.  Train Accuracy: %94.526
# Epoch: 7/3000,  Iteration: 2150,  Train loss: 0.186,  Train MSE: 75.2710,  0.1s /batch.  Train Accuracy: %95.582
# Epoch: 7/3000,  Iteration: 2175,  Train loss: 0.186,  Train MSE: 72.8453,  0.1s /batch.  Train Accuracy: %95.574
#
# Validation loss: 0.186,  Validation mse: 81.7829,  Validation accuracy: %95.048,
#
# Epoch: 7/3000,  Iteration: 2200,  Train loss: 0.186,  Train MSE: 83.0193,  0.1s /batch.  Train Accuracy: %94.863
# Epoch: 7/3000,  Iteration: 2225,  Train loss: 0.187,  Train MSE: 85.1896,  0.1s /batch.  Train Accuracy: %94.613
# Epoch: 8/3000,  Iteration: 2250,  Train loss: 0.187,  Train MSE: 76.3962,  0.1s /batch.  Train Accuracy: %95.298
#
# Validation loss: 0.186,  Validation mse: 82.8466,  Validation accuracy: %94.908,
#
# Epoch: 8/3000,  Iteration: 2275,  Train loss: 0.190,  Train MSE: 79.1672,  0.1s /batch.  Train Accuracy: %95.161
# Epoch: 8/3000,  Iteration: 2300,  Train loss: 0.187,  Train MSE: 78.5542,  0.1s /batch.  Train Accuracy: %95.254
# Epoch: 8/3000,  Iteration: 2325,  Train loss: 0.182,  Train MSE: 76.8832,  0.1s /batch.  Train Accuracy: %95.221
#
# Validation loss: 0.186,  Validation mse: 80.9799,  Validation accuracy: %95.096,
#
# Epoch: 8/3000,  Iteration: 2350,  Train loss: 0.186,  Train MSE: 69.5372,  0.1s /batch.  Train Accuracy: %95.807
# Epoch: 8/3000,  Iteration: 2375,  Train loss: 0.183,  Train MSE: 75.6110,  0.1s /batch.  Train Accuracy: %95.342
# Epoch: 8/3000,  Iteration: 2400,  Train loss: 0.185,  Train MSE: 68.6272,  0.1s /batch.  Train Accuracy: %95.890
#
# Validation loss: 0.186,  Validation mse: 94.2505,  Validation accuracy: %93.850,
#
# Epoch: 8/3000,  Iteration: 2425,  Train loss: 0.188,  Train MSE: 72.6982,  0.1s /batch.  Train Accuracy: %95.638
# Epoch: 8/3000,  Iteration: 2450,  Train loss: 0.182,  Train MSE: 72.3539,  0.1s /batch.  Train Accuracy: %95.565
# Epoch: 8/3000,  Iteration: 2475,  Train loss: 0.189,  Train MSE: 73.8838,  0.1s /batch.  Train Accuracy: %95.513
#
# Validation loss: 0.185,  Validation mse: 80.5250,  Validation accuracy: %95.057,
#
# Epoch: 8/3000,  Iteration: 2500,  Train loss: 0.184,  Train MSE: 68.4322,  0.1s /batch.  Train Accuracy: %95.962
# Epoch: 8/3000,  Iteration: 2525,  Train loss: 0.187,  Train MSE: 70.6905,  0.1s /batch.  Train Accuracy: %95.761
# Epoch: 8/3000,  Iteration: 2550,  Train loss: 0.187,  Train MSE: 73.6385,  0.1s /batch.  Train Accuracy: %95.563
#
# Validation loss: 0.185,  Validation mse: 81.2965,  Validation accuracy: %95.036,
#
# Epoch: 9/3000,  Iteration: 2575,  Train loss: 0.184,  Train MSE: 70.5607,  0.1s /batch.  Train Accuracy: %95.765
# Epoch: 9/3000,  Iteration: 2600,  Train loss: 0.190,  Train MSE: 73.1349,  0.1s /batch.  Train Accuracy: %95.508
# Epoch: 9/3000,  Iteration: 2625,  Train loss: 0.188,  Train MSE: 73.2439,  0.1s /batch.  Train Accuracy: %95.710
#
# Validation loss: 0.186,  Validation mse: 87.4451,  Validation accuracy: %94.818,
#
# Epoch: 9/3000,  Iteration: 2650,  Train loss: 0.185,  Train MSE: 70.5085,  0.1s /batch.  Train Accuracy: %95.699
# Epoch: 9/3000,  Iteration: 2675,  Train loss: 0.189,  Train MSE: 69.9488,  0.1s /batch.  Train Accuracy: %95.734
# Epoch: 9/3000,  Iteration: 2700,  Train loss: 0.184,  Train MSE: 70.0048,  0.1s /batch.  Train Accuracy: %95.884
#
# Validation loss: 0.185,  Validation mse: 81.0292,  Validation accuracy: %95.150,
#
# Epoch: 9/3000,  Iteration: 2725,  Train loss: 0.186,  Train MSE: 77.6214,  0.1s /batch.  Train Accuracy: %95.113
# Epoch: 9/3000,  Iteration: 2750,  Train loss: 0.190,  Train MSE: 77.5609,  0.1s /batch.  Train Accuracy: %95.344
# Epoch: 9/3000,  Iteration: 2775,  Train loss: 0.186,  Train MSE: 71.5963,  0.1s /batch.  Train Accuracy: %95.654
#
# Validation loss: 0.185,  Validation mse: 83.6756,  Validation accuracy: %94.875,
#
# Epoch: 9/3000,  Iteration: 2800,  Train loss: 0.182,  Train MSE: 72.0850,  0.1s /batch.  Train Accuracy: %95.805
# Epoch: 9/3000,  Iteration: 2825,  Train loss: 0.188,  Train MSE: 67.3300,  0.1s /batch.  Train Accuracy: %96.007
# Epoch: 9/3000,  Iteration: 2850,  Train loss: 0.185,  Train MSE: 73.3179,  0.1s /batch.  Train Accuracy: %95.449
#
# Validation loss: 0.185,  Validation mse: 80.2935,  Validation accuracy: %95.033,
#
# Epoch: 9/3000,  Iteration: 2875,  Train loss: 0.183,  Train MSE: 71.7049,  0.1s /batch.  Train Accuracy: %95.655
# Epoch: 10/3000,  Iteration: 2900,  Train loss: 0.189,  Train MSE: 69.6226,  0.1s /batch.  Train Accuracy: %95.816
# Epoch: 10/3000,  Iteration: 2925,  Train loss: 0.187,  Train MSE: 66.8441,  0.1s /batch.  Train Accuracy: %96.007
#
# Validation loss: 0.185,  Validation mse: 76.4441,  Validation accuracy: %95.340,
# Epoch: 10/3000,  Iteration: 2950,  Train loss: 0.186,  Train MSE: 68.4718,  0.1s /batch.  Train Accuracy: %95.850
# Epoch: 10/3000,  Iteration: 2975,  Train loss: 0.188,  Train MSE: 62.7323,  0.1s /batch.  Train Accuracy: %96.261
# Epoch: 10/3000,  Iteration: 3000,  Train loss: 0.185,  Train MSE: 67.9697,  0.1s /batch.  Train Accuracy: %95.992
#
# Validation loss: 0.185,  Validation mse: 75.5830,  Validation accuracy: %95.388,
#
# Epoch: 10/3000,  Iteration: 3025,  Train loss: 0.187,  Train MSE: 70.7310,  0.1s /batch.  Train Accuracy: %95.675
# Epoch: 10/3000,  Iteration: 3050,  Train loss: 0.183,  Train MSE: 64.3481,  0.1s /batch.  Train Accuracy: %96.161
# Epoch: 10/3000,  Iteration: 3075,  Train loss: 0.190,  Train MSE: 81.2186,  0.1s /batch.  Train Accuracy: %94.767
#
# Validation loss: 0.185,  Validation mse: 74.6233,  Validation accuracy: %95.466,
#
# Epoch: 10/3000,  Iteration: 3100,  Train loss: 0.183,  Train MSE: 66.3341,  0.1s /batch.  Train Accuracy: %96.021
# Epoch: 10/3000,  Iteration: 3125,  Train loss: 0.188,  Train MSE: 69.5724,  0.1s /batch.  Train Accuracy: %95.873
# Epoch: 10/3000,  Iteration: 3150,  Train loss: 0.185,  Train MSE: 65.7464,  0.1s /batch.  Train Accuracy: %96.123
#
# Validation loss: 0.185,  Validation mse: 76.8456,  Validation accuracy: %95.346,
#
# Epoch: 10/3000,  Iteration: 3175,  Train loss: 0.183,  Train MSE: 64.8913,  0.1s /batch.  Train Accuracy: %96.088
# Epoch: 10/3000,  Iteration: 3200,  Train loss: 0.183,  Train MSE: 62.6209,  0.1s /batch.  Train Accuracy: %96.308
# Epoch: 11/3000,  Iteration: 3225,  Train loss: 0.187,  Train MSE: 75.4912,  0.1s /batch.  Train Accuracy: %95.262
#
# Validation loss: 0.185,  Validation mse: 81.2640,  Validation accuracy: %94.996,
#
# Epoch: 11/3000,  Iteration: 3250,  Train loss: 0.187,  Train MSE: 64.7734,  0.1s /batch.  Train Accuracy: %96.092
# Epoch: 11/3000,  Iteration: 3275,  Train loss: 0.185,  Train MSE: 68.4286,  0.1s /batch.  Train Accuracy: %95.901
# Epoch: 11/3000,  Iteration: 3300,  Train loss: 0.177,  Train MSE: 60.1950,  0.1s /batch.  Train Accuracy: %96.407
#
# Validation loss: 0.185,  Validation mse: 74.3710,  Validation accuracy: %95.478,
#
# Epoch: 11/3000,  Iteration: 3325,  Train loss: 0.185,  Train MSE: 67.2572,  0.1s /batch.  Train Accuracy: %95.958
# Epoch: 11/3000,  Iteration: 3350,  Train loss: 0.180,  Train MSE: 65.1003,  0.1s /batch.  Train Accuracy: %96.125
# Epoch: 11/3000,  Iteration: 3375,  Train loss: 0.185,  Train MSE: 66.5519,  0.1s /batch.  Train Accuracy: %96.085
#
# Validation loss: 0.185,  Validation mse: 80.3115,  Validation accuracy: %95.192,
#
# Epoch: 11/3000,  Iteration: 3400,  Train loss: 0.183,  Train MSE: 79.4345,  0.1s /batch.  Train Accuracy: %95.033
# Epoch: 11/3000,  Iteration: 3425,  Train loss: 0.188,  Train MSE: 78.3197,  0.1s /batch.  Train Accuracy: %95.112
# Epoch: 11/3000,  Iteration: 3450,  Train loss: 0.184,  Train MSE: 73.0660,  0.1s /batch.  Train Accuracy: %95.368
#
# Validation loss: 0.185,  Validation mse: 73.3897,  Validation accuracy: %95.488,
#
# Epoch: 11/3000,  Iteration: 3475,  Train loss: 0.187,  Train MSE: 74.0308,  0.1s /batch.  Train Accuracy: %95.318
# Epoch: 11/3000,  Iteration: 3500,  Train loss: 0.188,  Train MSE: 61.4610,  0.1s /batch.  Train Accuracy: %96.337
# Epoch: 11/3000,  Iteration: 3525,  Train loss: 0.183,  Train MSE: 66.4161,  0.1s /batch.  Train Accuracy: %96.033
#
# Validation loss: 0.185,  Validation mse: 73.2934,  Validation accuracy: %95.550,
#
# Epoch: 12/3000,  Iteration: 3550,  Train loss: 0.180,  Train MSE: 68.2765,  0.1s /batch.  Train Accuracy: %95.830
# Epoch: 12/3000,  Iteration: 3575,  Train loss: 0.188,  Train MSE: 66.4860,  0.1s /batch.  Train Accuracy: %95.952
# Epoch: 12/3000,  Iteration: 3600,  Train loss: 0.180,  Train MSE: 67.1375,  0.1s /batch.  Train Accuracy: %95.856
#
# Validation loss: 0.185,  Validation mse: 73.3565,  Validation accuracy: %95.502,
#
# Epoch: 12/3000,  Iteration: 3625,  Train loss: 0.186,  Train MSE: 68.0976,  0.1s /batch.  Train Accuracy: %95.903
# Epoch: 12/3000,  Iteration: 3650,  Train loss: 0.186,  Train MSE: 62.9263,  0.1s /batch.  Train Accuracy: %96.252
# Epoch: 12/3000,  Iteration: 3675,  Train loss: 0.187,  Train MSE: 65.3209,  0.1s /batch.  Train Accuracy: %96.099
#
# Validation loss: 0.185,  Validation mse: 72.6928,  Validation accuracy: %95.559,
#
# Epoch: 12/3000,  Iteration: 3700,  Train loss: 0.183,  Train MSE: 62.6529,  0.1s /batch.  Train Accuracy: %96.261
# Epoch: 12/3000,  Iteration: 3725,  Train loss: 0.187,  Train MSE: 63.8108,  0.1s /batch.  Train Accuracy: %96.252
# Epoch: 12/3000,  Iteration: 3750,  Train loss: 0.187,  Train MSE: 60.7484,  0.1s /batch.  Train Accuracy: %96.367
#
# Validation loss: 0.185,  Validation mse: 78.1431,  Validation accuracy: %95.263,
#
# Epoch: 12/3000,  Iteration: 3775,  Train loss: 0.184,  Train MSE: 61.4857,  0.1s /batch.  Train Accuracy: %96.358
# Epoch: 12/3000,  Iteration: 3800,  Train loss: 0.190,  Train MSE: 71.6729,  0.1s /batch.  Train Accuracy: %95.706
# Epoch: 12/3000,  Iteration: 3825,  Train loss: 0.186,  Train MSE: 66.3596,  0.1s /batch.  Train Accuracy: %96.086
#
# Validation loss: 0.185,  Validation mse: 72.8866,  Validation accuracy: %95.627,
#
# Epoch: 12/3000,  Iteration: 3850,  Train loss: 0.183,  Train MSE: 64.1820,  0.1s /batch.  Train Accuracy: %96.119
# Epoch: 13/3000,  Iteration: 3875,  Train loss: 0.186,  Train MSE: 72.7457,  0.1s /batch.  Train Accuracy: %95.365
# Epoch: 13/3000,  Iteration: 3900,  Train loss: 0.181,  Train MSE: 62.6968,  0.1s /batch.  Train Accuracy: %96.286
#
# Validation loss: 0.185,  Validation mse: 72.8644,  Validation accuracy: %95.551,
#
# Epoch: 13/3000,  Iteration: 3925,  Train loss: 0.186,  Train MSE: 66.2603,  0.1s /batch.  Train Accuracy: %95.933
# Epoch: 13/3000,  Iteration: 3950,  Train loss: 0.184,  Train MSE: 65.0621,  0.1s /batch.  Train Accuracy: %96.092
# Epoch: 13/3000,  Iteration: 3975,  Train loss: 0.187,  Train MSE: 62.5193,  0.1s /batch.  Train Accuracy: %96.296
#
# Validation loss: 0.185,  Validation mse: 72.9875,  Validation accuracy: %95.581,
#
# Epoch: 13/3000,  Iteration: 4000,  Train loss: 0.186,  Train MSE: 61.9618,  0.1s /batch.  Train Accuracy: %96.305
# Epoch: 13/3000,  Iteration: 4025,  Train loss: 0.188,  Train MSE: 64.8057,  0.1s /batch.  Train Accuracy: %96.159
# Epoch: 13/3000,  Iteration: 4050,  Train loss: 0.185,  Train MSE: 65.2121,  0.1s /batch.  Train Accuracy: %96.027
#
# Validation loss: 0.185,  Validation mse: 73.7661,  Validation accuracy: %95.485,
#
# Epoch: 13/3000,  Iteration: 4075,  Train loss: 0.183,  Train MSE: 66.8309,  0.1s /batch.  Train Accuracy: %95.984
# Epoch: 13/3000,  Iteration: 4100,  Train loss: 0.184,  Train MSE: 63.6030,  0.1s /batch.  Train Accuracy: %96.189
# Epoch: 13/3000,  Iteration: 4125,  Train loss: 0.185,  Train MSE: 67.8535,  0.1s /batch.  Train Accuracy: %95.880
#
# Validation loss: 0.185,  Validation mse: 72.9990,  Validation accuracy: %95.504,
#
# Epoch: 13/3000,  Iteration: 4150,  Train loss: 0.181,  Train MSE: 61.5156,  0.1s /batch.  Train Accuracy: %96.440
# Epoch: 14/3000,  Iteration: 4175,  Train loss: 0.185,  Train MSE: 72.6327,  0.1s /batch.  Train Accuracy: %95.649
# Epoch: 14/3000,  Iteration: 4200,  Train loss: 0.188,  Train MSE: 65.9238,  0.1s /batch.  Train Accuracy: %95.955
#
# Validation loss: 0.185,  Validation mse: 78.9604,  Validation accuracy: %95.238,
#
# Epoch: 14/3000,  Iteration: 4225,  Train loss: 0.185,  Train MSE: 68.2896,  0.1s /batch.  Train Accuracy: %95.861
# Epoch: 14/3000,  Iteration: 4250,  Train loss: 0.183,  Train MSE: 58.7772,  0.1s /batch.  Train Accuracy: %96.472
# Epoch: 14/3000,  Iteration: 4275,  Train loss: 0.185,  Train MSE: 62.8678,  0.1s /batch.  Train Accuracy: %96.360
#
# Validation loss: 0.184,  Validation mse: 71.5055,  Validation accuracy: %95.674,
#
# Epoch: 14/3000,  Iteration: 4300,  Train loss: 0.186,  Train MSE: 61.2142,  0.1s /batch.  Train Accuracy: %96.315
# Epoch: 14/3000,  Iteration: 4325,  Train loss: 0.185,  Train MSE: 72.5108,  0.1s /batch.  Train Accuracy: %95.424
# Epoch: 14/3000,  Iteration: 4350,  Train loss: 0.186,  Train MSE: 65.4774,  0.1s /batch.  Train Accuracy: %96.062
#
# Validation loss: 0.184,  Validation mse: 69.9056,  Validation accuracy: %95.705,
#
# Epoch: 14/3000,  Iteration: 4375,  Train loss: 0.183,  Train MSE: 68.7366,  0.1s /batch.  Train Accuracy: %95.872
# Epoch: 14/3000,  Iteration: 4400,  Train loss: 0.185,  Train MSE: 58.7759,  0.1s /batch.  Train Accuracy: %96.494
# Epoch: 14/3000,  Iteration: 4425,  Train loss: 0.185,  Train MSE: 67.9645,  0.1s /batch.  Train Accuracy: %95.994
#
# Validation loss: 0.184,  Validation mse: 71.6105,  Validation accuracy: %95.656,
#
# Epoch: 14/3000,  Iteration: 4450,  Train loss: 0.183,  Train MSE: 61.2404,  0.1s /batch.  Train Accuracy: %96.390
# Epoch: 14/3000,  Iteration: 4475,  Train loss: 0.180,  Train MSE: 60.0719,  0.1s /batch.  Train Accuracy: %96.334
# Epoch: 15/3000,  Iteration: 4500,  Train loss: 0.181,  Train MSE: 64.5084,  0.1s /batch.  Train Accuracy: %96.150
#
# Validation loss: 0.184,  Validation mse: 69.7258,  Validation accuracy: %95.769,
#
# Epoch: 15/3000,  Iteration: 4525,  Train loss: 0.183,  Train MSE: 73.8165,  0.1s /batch.  Train Accuracy: %95.462
# Epoch: 15/3000,  Iteration: 4550,  Train loss: 0.187,  Train MSE: 62.4371,  0.1s /batch.  Train Accuracy: %96.277
# Epoch: 15/3000,  Iteration: 4575,  Train loss: 0.186,  Train MSE: 60.9068,  0.1s /batch.  Train Accuracy: %96.401
#
# Validation loss: 0.184,  Validation mse: 72.5545,  Validation accuracy: %95.545,
#
# Epoch: 15/3000,  Iteration: 4600,  Train loss: 0.187,  Train MSE: 62.5987,  0.1s /batch.  Train Accuracy: %96.259
# Epoch: 15/3000,  Iteration: 4625,  Train loss: 0.184,  Train MSE: 59.7249,  0.1s /batch.  Train Accuracy: %96.447
# Epoch: 15/3000,  Iteration: 4650,  Train loss: 0.181,  Train MSE: 62.5052,  0.1s /batch.  Train Accuracy: %96.291
#
# Validation loss: 0.185,  Validation mse: 75.2566,  Validation accuracy: %95.353,
#
# Epoch: 15/3000,  Iteration: 4675,  Train loss: 0.183,  Train MSE: 62.0490,  0.1s /batch.  Train Accuracy: %96.288
# Epoch: 15/3000,  Iteration: 4700,  Train loss: 0.180,  Train MSE: 60.2389,  0.1s /batch.  Train Accuracy: %96.348
# Epoch: 15/3000,  Iteration: 4725,  Train loss: 0.181,  Train MSE: 58.9700,  0.1s /batch.  Train Accuracy: %96.505
#
# Validation loss: 0.184,  Validation mse: 68.5432,  Validation accuracy: %95.853,
#
# Epoch: 15/3000,  Iteration: 4750,  Train loss: 0.184,  Train MSE: 62.6774,  0.1s /batch.  Train Accuracy: %96.374
# Epoch: 15/3000,  Iteration: 4775,  Train loss: 0.184,  Train MSE: 60.5299,  0.1s /batch.  Train Accuracy: %96.420
# Epoch: 15/3000,  Iteration: 4800,  Train loss: 0.186,  Train MSE: 64.7258,  0.1s /batch.  Train Accuracy: %96.013
#
# Validation loss: 0.184,  Validation mse: 73.6186,  Validation accuracy: %95.529,
#
# Epoch: 16/3000,  Iteration: 4825,  Train loss: 0.184,  Train MSE: 63.0419,  0.1s /batch.  Train Accuracy: %96.187
# Epoch: 16/3000,  Iteration: 4850,  Train loss: 0.190,  Train MSE: 65.1270,  0.1s /batch.  Train Accuracy: %96.084
# Epoch: 16/3000,  Iteration: 4875,  Train loss: 0.186,  Train MSE: 59.2798,  0.1s /batch.  Train Accuracy: %96.464
#
# Validation loss: 0.184,  Validation mse: 70.2804,  Validation accuracy: %95.685,
#
# Epoch: 16/3000,  Iteration: 4900,  Train loss: 0.183,  Train MSE: 56.9688,  0.1s /batch.  Train Accuracy: %96.631
# Epoch: 16/3000,  Iteration: 4925,  Train loss: 0.183,  Train MSE: 60.4754,  0.1s /batch.  Train Accuracy: %96.435
# Epoch: 16/3000,  Iteration: 4950,  Train loss: 0.187,  Train MSE: 61.3912,  0.1s /batch.  Train Accuracy: %96.199
#
# Validation loss: 0.184,  Validation mse: 68.9562,  Validation accuracy: %95.779,
#
# Epoch: 16/3000,  Iteration: 4975,  Train loss: 0.186,  Train MSE: 60.8761,  0.1s /batch.  Train Accuracy: %96.449
# Epoch: 16/3000,  Iteration: 5000,  Train loss: 0.183,  Train MSE: 56.1111,  0.1s /batch.  Train Accuracy: %96.709
# Epoch: 16/3000,  Iteration: 5025,  Train loss: 0.185,  Train MSE: 56.4868,  0.1s /batch.  Train Accuracy: %96.667
#
# Validation loss: 0.184,  Validation mse: 73.9093,  Validation accuracy: %95.381,
#
# Epoch: 16/3000,  Iteration: 5050,  Train loss: 0.184,  Train MSE: 56.7487,  0.1s /batch.  Train Accuracy: %96.680
# Epoch: 16/3000,  Iteration: 5075,  Train loss: 0.186,  Train MSE: 62.2565,  0.1s /batch.  Train Accuracy: %96.306
# Epoch: 16/3000,  Iteration: 5100,  Train loss: 0.182,  Train MSE: 57.8850,  0.1s /batch.  Train Accuracy: %96.534
#
# Validation loss: 0.184,  Validation mse: 68.0799,  Validation accuracy: %95.899,
#
# Epoch: 16/3000,  Iteration: 5125,  Train loss: 0.189,  Train MSE: 55.1956,  0.1s /batch.  Train Accuracy: %96.732
# Epoch: 17/3000,  Iteration: 5150,  Train loss: 0.180,  Train MSE: 58.5049,  0.1s /batch.  Train Accuracy: %96.497
# Epoch: 17/3000,  Iteration: 5175,  Train loss: 0.181,  Train MSE: 59.9288,  0.1s /batch.  Train Accuracy: %96.440
#
# Validation loss: 0.184,  Validation mse: 70.1637,  Validation accuracy: %95.735,
#
# Epoch: 17/3000,  Iteration: 5200,  Train loss: 0.188,  Train MSE: 59.2391,  0.1s /batch.  Train Accuracy: %96.465
# Epoch: 17/3000,  Iteration: 5225,  Train loss: 0.185,  Train MSE: 63.6626,  0.1s /batch.  Train Accuracy: %96.160
# Epoch: 17/3000,  Iteration: 5250,  Train loss: 0.185,  Train MSE: 59.3373,  0.1s /batch.  Train Accuracy: %96.393
#
# Validation loss: 0.184,  Validation mse: 69.5895,  Validation accuracy: %95.738,
#
# Epoch: 17/3000,  Iteration: 5275,  Train loss: 0.183,  Train MSE: 57.7391,  0.1s /batch.  Train Accuracy: %96.572
# Epoch: 17/3000,  Iteration: 5300,  Train loss: 0.185,  Train MSE: 62.0266,  0.1s /batch.  Train Accuracy: %96.223
# Epoch: 17/3000,  Iteration: 5325,  Train loss: 0.185,  Train MSE: 57.2819,  0.1s /batch.  Train Accuracy: %96.689
#
# Validation loss: 0.184,  Validation mse: 69.7863,  Validation accuracy: %95.725,
#
# Epoch: 17/3000,  Iteration: 5350,  Train loss: 0.189,  Train MSE: 60.1829,  0.1s /batch.  Train Accuracy: %96.343
# Epoch: 17/3000,  Iteration: 5375,  Train loss: 0.190,  Train MSE: 54.0924,  0.1s /batch.  Train Accuracy: %96.838
# Epoch: 17/3000,  Iteration: 5400,  Train loss: 0.189,  Train MSE: 66.2331,  0.1s /batch.  Train Accuracy: %95.828
#
# Validation loss: 0.184,  Validation mse: 73.9208,  Validation accuracy: %95.373,
#
# Epoch: 17/3000,  Iteration: 5425,  Train loss: 0.184,  Train MSE: 58.2866,  0.1s /batch.  Train Accuracy: %96.580
# Epoch: 17/3000,  Iteration: 5450,  Train loss: 0.187,  Train MSE: 57.5083,  0.1s /batch.  Train Accuracy: %96.699
# Epoch: 18/3000,  Iteration: 5475,  Train loss: 0.183,  Train MSE: 61.6270,  0.1s /batch.  Train Accuracy: %96.317
#
# Validation loss: 0.184,  Validation mse: 70.9197,  Validation accuracy: %95.695,
#
# Epoch: 18/3000,  Iteration: 5500,  Train loss: 0.190,  Train MSE: 65.3620,  0.1s /batch.  Train Accuracy: %96.086
# Epoch: 18/3000,  Iteration: 5525,  Train loss: 0.189,  Train MSE: 64.7993,  0.1s /batch.  Train Accuracy: %96.137
# Epoch: 18/3000,  Iteration: 5550,  Train loss: 0.185,  Train MSE: 58.4878,  0.1s /batch.  Train Accuracy: %96.572
#
# Validation loss: 0.184,  Validation mse: 67.3836,  Validation accuracy: %95.927,
#
# Epoch: 18/3000,  Iteration: 5575,  Train loss: 0.188,  Train MSE: 61.0878,  0.1s /batch.  Train Accuracy: %96.406
# Epoch: 18/3000,  Iteration: 5600,  Train loss: 0.188,  Train MSE: 59.0303,  0.1s /batch.  Train Accuracy: %96.558
# Epoch: 18/3000,  Iteration: 5625,  Train loss: 0.187,  Train MSE: 58.6954,  0.1s /batch.  Train Accuracy: %96.511
#
# Validation loss: 0.184,  Validation mse: 69.5634,  Validation accuracy: %95.730,
#
# Epoch: 18/3000,  Iteration: 5650,  Train loss: 0.182,  Train MSE: 69.2234,  0.1s /batch.  Train Accuracy: %95.828
# Epoch: 18/3000,  Iteration: 5675,  Train loss: 0.181,  Train MSE: 53.6864,  0.1s /batch.  Train Accuracy: %96.902
# Epoch: 18/3000,  Iteration: 5700,  Train loss: 0.186,  Train MSE: 59.8183,  0.1s /batch.  Train Accuracy: %96.467
#
# Validation loss: 0.184,  Validation mse: 68.5115,  Validation accuracy: %95.886,
#
# Epoch: 18/3000,  Iteration: 5725,  Train loss: 0.185,  Train MSE: 55.2829,  0.1s /batch.  Train Accuracy: %96.759
# Epoch: 18/3000,  Iteration: 5750,  Train loss: 0.181,  Train MSE: 57.2840,  0.1s /batch.  Train Accuracy: %96.554
# Epoch: 18/3000,  Iteration: 5775,  Train loss: 0.180,  Train MSE: 54.7342,  0.1s /batch.  Train Accuracy: %96.750
#
# Validation loss: 0.184,  Validation mse: 67.3248,  Validation accuracy: %95.885,
#
# Epoch: 19/3000,  Iteration: 5800,  Train loss: 0.191,  Train MSE: 60.5801,  0.1s /batch.  Train Accuracy: %96.211
# Epoch: 19/3000,  Iteration: 5825,  Train loss: 0.182,  Train MSE: 55.4763,  0.1s /batch.  Train Accuracy: %96.725
# Epoch: 19/3000,  Iteration: 5850,  Train loss: 0.181,  Train MSE: 56.3380,  0.1s /batch.  Train Accuracy: %96.669
#
# Validation loss: 0.184,  Validation mse: 68.5318,  Validation accuracy: %95.822,
# Epoch: 19/3000,  Iteration: 5875,  Train loss: 0.182,  Train MSE: 59.3898,  0.1s /batch.  Train Accuracy: %96.492
# Epoch: 19/3000,  Iteration: 5900,  Train loss: 0.187,  Train MSE: 56.6462,  0.1s /batch.  Train Accuracy: %96.733
# Epoch: 19/3000,  Iteration: 5925,  Train loss: 0.187,  Train MSE: 55.3156,  0.1s /batch.  Train Accuracy: %96.750
#
# Validation loss: 0.184,  Validation mse: 68.1546,  Validation accuracy: %95.858,
#
# Epoch: 19/3000,  Iteration: 5950,  Train loss: 0.181,  Train MSE: 53.8052,  0.1s /batch.  Train Accuracy: %96.807
# Epoch: 19/3000,  Iteration: 5975,  Train loss: 0.185,  Train MSE: 62.1080,  0.1s /batch.  Train Accuracy: %96.179
# Epoch: 19/3000,  Iteration: 6000,  Train loss: 0.189,  Train MSE: 60.2847,  0.1s /batch.  Train Accuracy: %96.429
#
# Validation loss: 0.184,  Validation mse: 67.9803,  Validation accuracy: %95.922,
#
# Epoch: 19/3000,  Iteration: 6025,  Train loss: 0.186,  Train MSE: 57.1514,  0.1s /batch.  Train Accuracy: %96.594
# Epoch: 19/3000,  Iteration: 6050,  Train loss: 0.185,  Train MSE: 57.1676,  0.1s /batch.  Train Accuracy: %96.536
# Epoch: 19/3000,  Iteration: 6075,  Train loss: 0.187,  Train MSE: 53.8459,  0.1s /batch.  Train Accuracy: %96.792
#
# Validation loss: 0.184,  Validation mse: 68.6775,  Validation accuracy: %95.799,
#
# Epoch: 20/3000,  Iteration: 6100,  Train loss: 0.186,  Train MSE: 53.8458,  0.1s /batch.  Train Accuracy: %96.881
# Epoch: 20/3000,  Iteration: 6125,  Train loss: 0.183,  Train MSE: 56.7032,  0.1s /batch.  Train Accuracy: %96.667
# Epoch: 20/3000,  Iteration: 6150,  Train loss: 0.182,  Train MSE: 54.1923,  0.1s /batch.  Train Accuracy: %96.830
#
# Validation loss: 0.184,  Validation mse: 70.2833,  Validation accuracy: %95.712,
#
# Epoch: 20/3000,  Iteration: 6175,  Train loss: 0.182,  Train MSE: 58.2774,  0.1s /batch.  Train Accuracy: %96.518
# Epoch: 20/3000,  Iteration: 6200,  Train loss: 0.182,  Train MSE: 54.6536,  0.1s /batch.  Train Accuracy: %96.884
# Epoch: 20/3000,  Iteration: 6225,  Train loss: 0.186,  Train MSE: 57.4051,  0.1s /batch.  Train Accuracy: %96.528
#
# Validation loss: 0.184,  Validation mse: 67.1924,  Validation accuracy: %95.909,
#
# Epoch: 20/3000,  Iteration: 6250,  Train loss: 0.183,  Train MSE: 65.0187,  0.1s /batch.  Train Accuracy: %95.939
# Epoch: 20/3000,  Iteration: 6275,  Train loss: 0.187,  Train MSE: 56.7128,  0.1s /batch.  Train Accuracy: %96.702
# Epoch: 20/3000,  Iteration: 6300,  Train loss: 0.182,  Train MSE: 60.1524,  0.1s /batch.  Train Accuracy: %96.377
#
# Validation loss: 0.184,  Validation mse: 70.6074,  Validation accuracy: %95.699,
#
# Epoch: 20/3000,  Iteration: 6325,  Train loss: 0.183,  Train MSE: 52.7288,  0.1s /batch.  Train Accuracy: %96.944
# Epoch: 20/3000,  Iteration: 6350,  Train loss: 0.184,  Train MSE: 55.4827,  0.1s /batch.  Train Accuracy: %96.700
# Epoch: 20/3000,  Iteration: 6375,  Train loss: 0.185,  Train MSE: 55.4672,  0.1s /batch.  Train Accuracy: %96.724
#
# Validation loss: 0.184,  Validation mse: 70.2034,  Validation accuracy: %95.809,
#
# Epoch: 20/3000,  Iteration: 6400,  Train loss: 0.185,  Train MSE: 53.9715,  0.1s /batch.  Train Accuracy: %96.929
# Epoch: 21/3000,  Iteration: 6425,  Train loss: 0.186,  Train MSE: 53.9672,  0.1s /batch.  Train Accuracy: %96.826
# Epoch: 21/3000,  Iteration: 6450,  Train loss: 0.185,  Train MSE: 55.1654,  0.1s /batch.  Train Accuracy: %96.762
#
# Validation loss: 0.184,  Validation mse: 74.3142,  Validation accuracy: %95.391,
#
# Epoch: 21/3000,  Iteration: 6475,  Train loss: 0.190,  Train MSE: 54.1000,  0.1s /batch.  Train Accuracy: %96.829
# Epoch: 21/3000,  Iteration: 6500,  Train loss: 0.184,  Train MSE: 53.2971,  0.1s /batch.  Train Accuracy: %96.891
# Epoch: 21/3000,  Iteration: 6525,  Train loss: 0.187,  Train MSE: 52.6574,  0.1s /batch.  Train Accuracy: %96.980
#
# Validation loss: 0.184,  Validation mse: 67.7416,  Validation accuracy: %95.889,
#
# Epoch: 21/3000,  Iteration: 6550,  Train loss: 0.183,  Train MSE: 53.0028,  0.1s /batch.  Train Accuracy: %96.868
# Epoch: 21/3000,  Iteration: 6575,  Train loss: 0.184,  Train MSE: 64.6066,  0.1s /batch.  Train Accuracy: %96.039
# Epoch: 21/3000,  Iteration: 6600,  Train loss: 0.183,  Train MSE: 53.3369,  0.1s /batch.  Train Accuracy: %96.897
#
# Validation loss: 0.184,  Validation mse: 68.4982,  Validation accuracy: %95.834,
#
# Epoch: 21/3000,  Iteration: 6625,  Train loss: 0.181,  Train MSE: 52.5305,  0.1s /batch.  Train Accuracy: %96.970
# Epoch: 21/3000,  Iteration: 6650,  Train loss: 0.185,  Train MSE: 53.3615,  0.1s /batch.  Train Accuracy: %96.836
# Epoch: 21/3000,  Iteration: 6675,  Train loss: 0.184,  Train MSE: 53.3343,  0.1s /batch.  Train Accuracy: %96.907
#
# Validation loss: 0.184,  Validation mse: 71.6245,  Validation accuracy: %95.662,
#
# Epoch: 21/3000,  Iteration: 6700,  Train loss: 0.181,  Train MSE: 52.7657,  0.1s /batch.  Train Accuracy: %96.848
# Epoch: 21/3000,  Iteration: 6725,  Train loss: 0.183,  Train MSE: 54.2729,  0.1s /batch.  Train Accuracy: %96.822
# Epoch: 22/3000,  Iteration: 6750,  Train loss: 0.180,  Train MSE: 58.9734,  0.1s /batch.  Train Accuracy: %96.450
#
# Validation loss: 0.184,  Validation mse: 70.4745,  Validation accuracy: %95.780,
#
# Epoch: 22/3000,  Iteration: 6775,  Train loss: 0.183,  Train MSE: 53.9831,  0.1s /batch.  Train Accuracy: %96.739
# Epoch: 22/3000,  Iteration: 6800,  Train loss: 0.182,  Train MSE: 52.0584,  0.1s /batch.  Train Accuracy: %96.965
# Epoch: 22/3000,  Iteration: 6825,  Train loss: 0.191,  Train MSE: 66.9481,  0.1s /batch.  Train Accuracy: %95.804
#
# Validation loss: 0.184,  Validation mse: 66.0697,  Validation accuracy: %95.987,
#
# Epoch: 22/3000,  Iteration: 6850,  Train loss: 0.177,  Train MSE: 50.1989,  0.1s /batch.  Train Accuracy: %97.125
# Epoch: 22/3000,  Iteration: 6875,  Train loss: 0.186,  Train MSE: 52.3314,  0.1s /batch.  Train Accuracy: %96.972
# Epoch: 22/3000,  Iteration: 6900,  Train loss: 0.182,  Train MSE: 57.7531,  0.1s /batch.  Train Accuracy: %96.541
#
# Validation loss: 0.184,  Validation mse: 69.6937,  Validation accuracy: %95.784,
#
# Epoch: 22/3000,  Iteration: 6925,  Train loss: 0.183,  Train MSE: 54.1991,  0.1s /batch.  Train Accuracy: %96.869
# Epoch: 22/3000,  Iteration: 6950,  Train loss: 0.180,  Train MSE: 52.6414,  0.1s /batch.  Train Accuracy: %96.902
# Epoch: 22/3000,  Iteration: 6975,  Train loss: 0.189,  Train MSE: 53.8295,  0.1s /batch.  Train Accuracy: %96.828
#
# Validation loss: 0.184,  Validation mse: 65.6032,  Validation accuracy: %96.036,
#
# Epoch: 22/3000,  Iteration: 7000,  Train loss: 0.187,  Train MSE: 51.0954,  0.1s /batch.  Train Accuracy: %97.077
# Epoch: 22/3000,  Iteration: 7025,  Train loss: 0.184,  Train MSE: 52.7725,  0.1s /batch.  Train Accuracy: %96.920
# Epoch: 22/3000,  Iteration: 7050,  Train loss: 0.183,  Train MSE: 52.8487,  0.1s /batch.  Train Accuracy: %97.017
#
# Validation loss: 0.184,  Validation mse: 65.0378,  Validation accuracy: %96.059,
#
# Epoch: 23/3000,  Iteration: 7075,  Train loss: 0.185,  Train MSE: 65.6132,  0.1s /batch.  Train Accuracy: %95.930
# Epoch: 23/3000,  Iteration: 7100,  Train loss: 0.183,  Train MSE: 51.5164,  0.1s /batch.  Train Accuracy: %97.013
# Epoch: 23/3000,  Iteration: 7125,  Train loss: 0.184,  Train MSE: 52.8696,  0.1s /batch.  Train Accuracy: %96.866
#
# Validation loss: 0.184,  Validation mse: 66.1504,  Validation accuracy: %95.996,
#
# Epoch: 23/3000,  Iteration: 7150,  Train loss: 0.181,  Train MSE: 52.3471,  0.1s /batch.  Train Accuracy: %96.964
# Epoch: 23/3000,  Iteration: 7175,  Train loss: 0.184,  Train MSE: 50.4285,  0.1s /batch.  Train Accuracy: %97.111
# Epoch: 23/3000,  Iteration: 7200,  Train loss: 0.185,  Train MSE: 48.3866,  0.1s /batch.  Train Accuracy: %97.277
#
# Validation loss: 0.184,  Validation mse: 66.4598,  Validation accuracy: %95.953,
#
# Epoch: 23/3000,  Iteration: 7225,  Train loss: 0.183,  Train MSE: 59.1367,  0.1s /batch.  Train Accuracy: %96.381
# Epoch: 23/3000,  Iteration: 7250,  Train loss: 0.186,  Train MSE: 52.7875,  0.1s /batch.  Train Accuracy: %96.910
# Epoch: 23/3000,  Iteration: 7275,  Train loss: 0.184,  Train MSE: 53.1767,  0.1s /batch.  Train Accuracy: %96.888
#
# Validation loss: 0.184,  Validation mse: 69.0412,  Validation accuracy: %95.796,
#
# Epoch: 23/3000,  Iteration: 7300,  Train loss: 0.185,  Train MSE: 50.9136,  0.1s /batch.  Train Accuracy: %97.014
# Epoch: 23/3000,  Iteration: 7325,  Train loss: 0.186,  Train MSE: 50.4125,  0.1s /batch.  Train Accuracy: %97.045
# Epoch: 23/3000,  Iteration: 7350,  Train loss: 0.184,  Train MSE: 51.0097,  0.1s /batch.  Train Accuracy: %97.064
#
# Validation loss: 0.184,  Validation mse: 66.9451,  Validation accuracy: %95.943,
#
# Epoch: 23/3000,  Iteration: 7375,  Train loss: 0.185,  Train MSE: 57.3269,  0.1s /batch.  Train Accuracy: %96.548
# Epoch: 24/3000,  Iteration: 7400,  Train loss: 0.185,  Train MSE: 65.3501,  0.1s /batch.  Train Accuracy: %96.113
# Epoch: 24/3000,  Iteration: 7425,  Train loss: 0.180,  Train MSE: 47.8083,  0.1s /batch.  Train Accuracy: %97.319
#
# Validation loss: 0.184,  Validation mse: 69.9015,  Validation accuracy: %95.797,
#
# Epoch: 24/3000,  Iteration: 7450,  Train loss: 0.182,  Train MSE: 51.6818,  0.1s /batch.  Train Accuracy: %96.945
# Epoch: 24/3000,  Iteration: 7475,  Train loss: 0.186,  Train MSE: 50.2728,  0.1s /batch.  Train Accuracy: %97.127
# Epoch: 24/3000,  Iteration: 7500,  Train loss: 0.183,  Train MSE: 57.7615,  0.1s /batch.  Train Accuracy: %96.609
#
# Validation loss: 0.184,  Validation mse: 66.2330,  Validation accuracy: %96.030,
#
# Epoch: 24/3000,  Iteration: 7525,  Train loss: 0.183,  Train MSE: 48.1643,  0.1s /batch.  Train Accuracy: %97.312
# Epoch: 24/3000,  Iteration: 7550,  Train loss: 0.186,  Train MSE: 55.3389,  0.1s /batch.  Train Accuracy: %96.736
# Epoch: 24/3000,  Iteration: 7575,  Train loss: 0.183,  Train MSE: 59.0302,  0.1s /batch.  Train Accuracy: %96.335
#
# Validation loss: 0.184,  Validation mse: 71.5245,  Validation accuracy: %95.702,
#
# Epoch: 24/3000,  Iteration: 7600,  Train loss: 0.188,  Train MSE: 57.2130,  0.1s /batch.  Train Accuracy: %96.613
# Epoch: 24/3000,  Iteration: 7625,  Train loss: 0.185,  Train MSE: 48.4898,  0.1s /batch.  Train Accuracy: %97.237
# Epoch: 24/3000,  Iteration: 7650,  Train loss: 0.181,  Train MSE: 49.8461,  0.1s /batch.  Train Accuracy: %97.137
#
# Validation loss: 0.184,  Validation mse: 68.9965,  Validation accuracy: %95.847,
#
# Epoch: 24/3000,  Iteration: 7675,  Train loss: 0.182,  Train MSE: 50.6428,  0.1s /batch.  Train Accuracy: %97.119
# Epoch: 24/3000,  Iteration: 7700,  Train loss: 0.183,  Train MSE: 57.3738,  0.1s /batch.  Train Accuracy: %96.575
# Epoch: 25/3000,  Iteration: 7725,  Train loss: 0.185,  Train MSE: 57.4893,  0.1s /batch.  Train Accuracy: %96.517
#
# Validation loss: 0.184,  Validation mse: 67.9293,  Validation accuracy: %95.847,
#
# Epoch: 25/3000,  Iteration: 7750,  Train loss: 0.186,  Train MSE: 52.2999,  0.1s /batch.  Train Accuracy: %96.949
# Epoch: 25/3000,  Iteration: 7775,  Train loss: 0.187,  Train MSE: 58.2117,  0.1s /batch.  Train Accuracy: %96.558
# Epoch: 25/3000,  Iteration: 7800,  Train loss: 0.187,  Train MSE: 53.9112,  0.1s /batch.  Train Accuracy: %96.805
#
# Validation loss: 0.184,  Validation mse: 75.0675,  Validation accuracy: %95.299,
#
# Epoch: 25/3000,  Iteration: 7825,  Train loss: 0.185,  Train MSE: 50.5178,  0.1s /batch.  Train Accuracy: %97.089
# Epoch: 25/3000,  Iteration: 7850,  Train loss: 0.184,  Train MSE: 50.5403,  0.1s /batch.  Train Accuracy: %97.084
# Epoch: 25/3000,  Iteration: 7875,  Train loss: 0.183,  Train MSE: 51.0202,  0.1s /batch.  Train Accuracy: %97.003
#
# Validation loss: 0.184,  Validation mse: 66.1052,  Validation accuracy: %95.996,
#
# Epoch: 25/3000,  Iteration: 7900,  Train loss: 0.183,  Train MSE: 55.3251,  0.1s /batch.  Train Accuracy: %96.762
# Epoch: 25/3000,  Iteration: 7925,  Train loss: 0.188,  Train MSE: 51.7040,  0.1s /batch.  Train Accuracy: %97.002
# Epoch: 25/3000,  Iteration: 7950,  Train loss: 0.182,  Train MSE: 49.7521,  0.1s /batch.  Train Accuracy: %97.105
#
# Validation loss: 0.184,  Validation mse: 65.7087,  Validation accuracy: %96.012,
#
# Epoch: 25/3000,  Iteration: 7975,  Train loss: 0.182,  Train MSE: 50.7716,  0.1s /batch.  Train Accuracy: %97.068
# Epoch: 25/3000,  Iteration: 8000,  Train loss: 0.182,  Train MSE: 54.8341,  0.1s /batch.  Train Accuracy: %96.679
# Epoch: 25/3000,  Iteration: 8025,  Train loss: 0.186,  Train MSE: 50.0300,  0.1s /batch.  Train Accuracy: %97.129
#
# Validation loss: 0.184,  Validation mse: 65.1484,  Validation accuracy: %96.055,
#
# Epoch: 26/3000,  Iteration: 8050,  Train loss: 0.184,  Train MSE: 49.2799,  0.1s /batch.  Train Accuracy: %97.201
# Epoch: 26/3000,  Iteration: 8075,  Train loss: 0.182,  Train MSE: 48.8574,  0.1s /batch.  Train Accuracy: %97.158
# Epoch: 26/3000,  Iteration: 8100,  Train loss: 0.181,  Train MSE: 49.3458,  0.1s /batch.  Train Accuracy: %97.188
#
# Validation loss: 0.184,  Validation mse: 67.1006,  Validation accuracy: %95.969,
#
# Epoch: 26/3000,  Iteration: 8125,  Train loss: 0.183,  Train MSE: 49.3698,  0.1s /batch.  Train Accuracy: %97.189
# Epoch: 26/3000,  Iteration: 8150,  Train loss: 0.185,  Train MSE: 48.9973,  0.1s /batch.  Train Accuracy: %97.228
# Epoch: 26/3000,  Iteration: 8175,  Train loss: 0.183,  Train MSE: 48.0909,  0.1s /batch.  Train Accuracy: %97.256
#
# Validation loss: 0.184,  Validation mse: 68.4190,  Validation accuracy: %95.854,
#
# Epoch: 26/3000,  Iteration: 8200,  Train loss: 0.184,  Train MSE: 51.0361,  0.1s /batch.  Train Accuracy: %97.067
# Epoch: 26/3000,  Iteration: 8225,  Train loss: 0.183,  Train MSE: 54.4999,  0.1s /batch.  Train Accuracy: %96.799
# Epoch: 26/3000,  Iteration: 8250,  Train loss: 0.186,  Train MSE: 50.3408,  0.1s /batch.  Train Accuracy: %97.131
#
# Validation loss: 0.183,  Validation mse: 63.5408,  Validation accuracy: %96.172,
#
# Epoch: 26/3000,  Iteration: 8275,  Train loss: 0.184,  Train MSE: 50.8342,  0.1s /batch.  Train Accuracy: %97.037
# Epoch: 26/3000,  Iteration: 8300,  Train loss: 0.185,  Train MSE: 55.8606,  0.1s /batch.  Train Accuracy: %96.717
# Epoch: 26/3000,  Iteration: 8325,  Train loss: 0.180,  Train MSE: 48.7070,  0.1s /batch.  Train Accuracy: %97.268
#
# Validation loss: 0.184,  Validation mse: 67.8126,  Validation accuracy: %95.878,
#
# Epoch: 27/3000,  Iteration: 8350,  Train loss: 0.185,  Train MSE: 48.4762,  0.1s /batch.  Train Accuracy: %97.185
# Epoch: 27/3000,  Iteration: 8375,  Train loss: 0.187,  Train MSE: 52.2035,  0.1s /batch.  Train Accuracy: %96.988
# Epoch: 27/3000,  Iteration: 8400,  Train loss: 0.184,  Train MSE: 48.2722,  0.1s /batch.  Train Accuracy: %97.245
#
# Validation loss: 0.184,  Validation mse: 67.3728,  Validation accuracy: %95.889,
#
# Epoch: 27/3000,  Iteration: 8425,  Train loss: 0.185,  Train MSE: 53.1677,  0.1s /batch.  Train Accuracy: %96.904
# Epoch: 27/3000,  Iteration: 8450,  Train loss: 0.180,  Train MSE: 47.0241,  0.1s /batch.  Train Accuracy: %97.372
# Epoch: 27/3000,  Iteration: 8475,  Train loss: 0.185,  Train MSE: 48.6849,  0.1s /batch.  Train Accuracy: %97.241
#
# Validation loss: 0.183,  Validation mse: 64.0296,  Validation accuracy: %96.145,
#
# ...
# Epoch: 33/3000,  Iteration: 10400,  Train loss: 0.180,  Train MSE: 49.1594,  0.1s /batch.  Train Accuracy: %97.153
# Epoch: 33/3000,  Iteration: 10425,  Train loss: 0.183,  Train MSE: 42.7068,  0.1s /batch.  Train Accuracy: %97.637
#
# Validation loss: 0.184,  Validation mse: 73.2896,  Validation accuracy: %95.408,
#
# Epoch: 33/3000,  Iteration: 10450,  Train loss: 0.185,  Train MSE: 47.9199,  0.1s /batch.  Train Accuracy: %97.285
# Epoch: 33/3000,  Iteration: 10475,  Train loss: 0.179,  Train MSE: 47.0332,  0.1s /batch.  Train Accuracy: %97.415
# Epoch: 33/3000,  Iteration: 10500,  Train loss: 0.186,  Train MSE: 46.6250,  0.1s /batch.  Train Accuracy: %97.358
#
# Validation loss: 0.183,  Validation mse: 66.8060,  Validation accuracy: %95.922,
#
# Epoch: 33/3000,  Iteration: 10525,  Train loss: 0.182,  Train MSE: 43.5823,  0.1s /batch.  Train Accuracy: %97.564
# Epoch: 33/3000,  Iteration: 10550,  Train loss: 0.184,  Train MSE: 47.7906,  0.1s /batch.  Train Accuracy: %97.281
# Epoch: 33/3000,  Iteration: 10575,  Train loss: 0.185,  Train MSE: 46.6549,  0.1s /batch.  Train Accuracy: %97.366
#
# Validation loss: 0.183,  Validation mse: 63.9080,  Validation accuracy: %96.130,
#
# Epoch: 34/3000,  Iteration: 10600,  Train loss: 0.181,  Train MSE: 45.7982,  0.1s /batch.  Train Accuracy: %97.450
# Epoch: 34/3000,  Iteration: 10625,  Train loss: 0.187,  Train MSE: 45.6269,  0.1s /batch.  Train Accuracy: %97.462
# Epoch: 34/3000,  Iteration: 10650,  Train loss: 0.185,  Train MSE: 48.7732,  0.1s /batch.  Train Accuracy: %97.353
#
# Validation loss: 0.183,  Validation mse: 65.8755,  Validation accuracy: %96.083,
#
# Epoch: 34/3000,  Iteration: 10675,  Train loss: 0.182,  Train MSE: 44.7722,  0.1s /batch.  Train Accuracy: %97.502
# Epoch: 34/3000,  Iteration: 10700,  Train loss: 0.186,  Train MSE: 44.2985,  0.1s /batch.  Train Accuracy: %97.531
# Epoch: 34/3000,  Iteration: 10725,  Train loss: 0.181,  Train MSE: 44.6268,  0.1s /batch.  Train Accuracy: %97.518
#
# Validation loss: 0.183,  Validation mse: 65.0597,  Validation accuracy: %96.075,
#
# Epoch: 34/3000,  Iteration: 10750,  Train loss: 0.183,  Train MSE: 46.5999,  0.1s /batch.  Train Accuracy: %97.375
# Epoch: 34/3000,  Iteration: 10775,  Train loss: 0.187,  Train MSE: 50.6435,  0.1s /batch.  Train Accuracy: %97.114
# Epoch: 34/3000,  Iteration: 10800,  Train loss: 0.184,  Train MSE: 48.2164,  0.1s /batch.  Train Accuracy: %97.279
#
# Validation loss: 0.183,  Validation mse: 65.9764,  Validation accuracy: %96.012,
#
# Epoch: 34/3000,  Iteration: 10825,  Train loss: 0.179,  Train MSE: 46.1171,  0.1s /batch.  Train Accuracy: %97.346
# Epoch: 34/3000,  Iteration: 10850,  Train loss: 0.186,  Train MSE: 44.1901,  0.1s /batch.  Train Accuracy: %97.593
# Epoch: 34/3000,  Iteration: 10875,  Train loss: 0.182,  Train MSE: 46.0707,  0.1s /batch.  Train Accuracy: %97.382
#
# Validation loss: 0.183,  Validation mse: 66.0458,  Validation accuracy: %95.987,
#
# Epoch: 34/3000,  Iteration: 10900,  Train loss: 0.180,  Train MSE: 44.5197,  0.1s /batch.  Train Accuracy: %97.570
# Epoch: 35/3000,  Iteration: 10925,  Train loss: 0.186,  Train MSE: 45.3514,  0.1s /batch.  Train Accuracy: %97.472
# Epoch: 35/3000,  Iteration: 10950,  Train loss: 0.184,  Train MSE: 46.2544,  0.1s /batch.  Train Accuracy: %97.394
#
# Validation loss: 0.183,  Validation mse: 64.9419,  Validation accuracy: %96.086,
#
# Epoch: 35/3000,  Iteration: 10975,  Train loss: 0.183,  Train MSE: 45.4398,  0.1s /batch.  Train Accuracy: %97.380
# Epoch: 35/3000,  Iteration: 11000,  Train loss: 0.186,  Train MSE: 42.8039,  0.1s /batch.  Train Accuracy: %97.697
# Epoch: 35/3000,  Iteration: 11025,  Train loss: 0.183,  Train MSE: 45.7136,  0.1s /batch.  Train Accuracy: %97.466
#
# Validation loss: 0.183,  Validation mse: 64.0960,  Validation accuracy: %96.109,
#
# Epoch: 35/3000,  Iteration: 11050,  Train loss: 0.185,  Train MSE: 48.2492,  0.1s /batch.  Train Accuracy: %97.217
# Epoch: 35/3000,  Iteration: 11075,  Train loss: 0.181,  Train MSE: 44.1142,  0.1s /batch.  Train Accuracy: %97.548
# Epoch: 35/3000,  Iteration: 11100,  Train loss: 0.188,  Train MSE: 52.8026,  0.1s /batch.  Train Accuracy: %96.883
#
# Validation loss: 0.183,  Validation mse: 67.8200,  Validation accuracy: %95.879,
#
# Epoch: 35/3000,  Iteration: 11125,  Train loss: 0.180,  Train MSE: 42.8861,  0.1s /batch.  Train Accuracy: %97.632
# Epoch: 35/3000,  Iteration: 11150,  Train loss: 0.185,  Train MSE: 44.1455,  0.1s /batch.  Train Accuracy: %97.614
# Epoch: 35/3000,  Iteration: 11175,  Train loss: 0.182,  Train MSE: 42.6223,  0.1s /batch.  Train Accuracy: %97.715
#
# Validation loss: 0.183,  Validation mse: 64.7057,  Validation accuracy: %96.086,
#
# Epoch: 35/3000,  Iteration: 11200,  Train loss: 0.181,  Train MSE: 44.7639,  0.1s /batch.  Train Accuracy: %97.477
# Epoch: 35/3000,  Iteration: 11225,  Train loss: 0.181,  Train MSE: 42.1016,  0.1s /batch.  Train Accuracy: %97.708
# Epoch: 36/3000,  Iteration: 11250,  Train loss: 0.184,  Train MSE: 47.9448,  0.1s /batch.  Train Accuracy: %97.300
#
# Validation loss: 0.183,  Validation mse: 68.0121,  Validation accuracy: %95.881,
#
# Epoch: 36/3000,  Iteration: 11275,  Train loss: 0.185,  Train MSE: 46.1602,  0.1s /batch.  Train Accuracy: %97.383
# Epoch: 36/3000,  Iteration: 11300,  Train loss: 0.183,  Train MSE: 45.3337,  0.1s /batch.  Train Accuracy: %97.423
# Epoch: 36/3000,  Iteration: 11325,  Train loss: 0.175,  Train MSE: 40.0801,  0.1s /batch.  Train Accuracy: %97.873
#
# Validation loss: 0.183,  Validation mse: 65.1644,  Validation accuracy: %96.090,
#
# Epoch: 36/3000,  Iteration: 11350,  Train loss: 0.183,  Train MSE: 44.3534,  0.1s /batch.  Train Accuracy: %97.520
# Epoch: 36/3000,  Iteration: 11375,  Train loss: 0.178,  Train MSE: 45.5226,  0.1s /batch.  Train Accuracy: %97.437
# Epoch: 36/3000,  Iteration: 11400,  Train loss: 0.182,  Train MSE: 44.1142,  0.1s /batch.  Train Accuracy: %97.628
#
# Validation loss: 0.183,  Validation mse: 68.7174,  Validation accuracy: %95.918,
#
# Epoch: 36/3000,  Iteration: 11425,  Train loss: 0.180,  Train MSE: 47.9852,  0.1s /batch.  Train Accuracy: %97.183
# Epoch: 36/3000,  Iteration: 11450,  Train loss: 0.186,  Train MSE: 48.8079,  0.1s /batch.  Train Accuracy: %97.215
# Epoch: 36/3000,  Iteration: 11475,  Train loss: 0.182,  Train MSE: 45.3670,  0.1s /batch.  Train Accuracy: %97.430
#
# Validation loss: 0.183,  Validation mse: 65.3400,  Validation accuracy: %96.055,
#
# Epoch: 36/3000,  Iteration: 11500,  Train loss: 0.184,  Train MSE: 47.0328,  0.1s /batch.  Train Accuracy: %97.298
# Epoch: 36/3000,  Iteration: 11525,  Train loss: 0.186,  Train MSE: 45.2598,  0.1s /batch.  Train Accuracy: %97.500
# Epoch: 36/3000,  Iteration: 11550,  Train loss: 0.181,  Train MSE: 42.2824,  0.1s /batch.  Train Accuracy: %97.747
#
# Validation loss: 0.183,  Validation mse: 64.7636,  Validation accuracy: %96.121,
#
# Epoch: 37/3000,  Iteration: 11575,  Train loss: 0.178,  Train MSE: 43.3437,  0.1s /batch.  Train Accuracy: %97.560
# Epoch: 37/3000,  Iteration: 11600,  Train loss: 0.185,  Train MSE: 44.7052,  0.1s /batch.  Train Accuracy: %97.522
# Epoch: 37/3000,  Iteration: 11625,  Train loss: 0.178,  Train MSE: 45.2924,  0.1s /batch.  Train Accuracy: %97.442
#
# Validation loss: 0.183,  Validation mse: 66.8745,  Validation accuracy: %95.938,
#
# Epoch: 37/3000,  Iteration: 11650,  Train loss: 0.183,  Train MSE: 45.0298,  0.1s /batch.  Train Accuracy: %97.500
# Epoch: 37/3000,  Iteration: 11675,  Train loss: 0.184,  Train MSE: 42.4523,  0.1s /batch.  Train Accuracy: %97.701
# Epoch: 37/3000,  Iteration: 11700,  Train loss: 0.185,  Train MSE: 42.6747,  0.1s /batch.  Train Accuracy: %97.660
#
# Validation loss: 0.183,  Validation mse: 64.3950,  Validation accuracy: %96.107,
#
# Epoch: 37/3000,  Iteration: 11725,  Train loss: 0.181,  Train MSE: 43.1755,  0.1s /batch.  Train Accuracy: %97.637
# Epoch: 37/3000,  Iteration: 11750,  Train loss: 0.185,  Train MSE: 44.1688,  0.1s /batch.  Train Accuracy: %97.556
# Epoch: 37/3000,  Iteration: 11775,  Train loss: 0.185,  Train MSE: 41.7462,  0.1s /batch.  Train Accuracy: %97.714
#
# Validation loss: 0.183,  Validation mse: 66.9161,  Validation accuracy: %95.931,
#
# Epoch: 37/3000,  Iteration: 11800,  Train loss: 0.182,  Train MSE: 41.6237,  0.1s /batch.  Train Accuracy: %97.711
# Epoch: 37/3000,  Iteration: 11825,  Train loss: 0.188,  Train MSE: 49.2025,  0.1s /batch.  Train Accuracy: %97.222
# Epoch: 37/3000,  Iteration: 11850,  Train loss: 0.184,  Train MSE: 48.4794,  0.1s /batch.  Train Accuracy: %97.294
#
# Validation loss: 0.183,  Validation mse: 65.5624,  Validation accuracy: %96.068,
#
# Epoch: 37/3000,  Iteration: 11875,  Train loss: 0.181,  Train MSE: 43.3419,  0.1s /batch.  Train Accuracy: %97.599
# Epoch: 38/3000,  Iteration: 11900,  Train loss: 0.184,  Train MSE: 47.8483,  0.1s /batch.  Train Accuracy: %97.305
# Epoch: 38/3000,  Iteration: 11925,  Train loss: 0.179,  Train MSE: 42.0629,  0.1s /batch.  Train Accuracy: %97.711
#
# Validation loss: 0.183,  Validation mse: 65.1774,  Validation accuracy: %96.055,
#
# Epoch: 38/3000,  Iteration: 11950,  Train loss: 0.184,  Train MSE: 46.2176,  0.1s /batch.  Train Accuracy: %97.372
# Epoch: 38/3000,  Iteration: 11975,  Train loss: 0.182,  Train MSE: 43.0844,  0.1s /batch.  Train Accuracy: %97.663
# Epoch: 38/3000,  Iteration: 12000,  Train loss: 0.185,  Train MSE: 42.3322,  0.1s /batch.  Train Accuracy: %97.708
#
# Validation loss: 0.183,  Validation mse: 63.2124,  Validation accuracy: %96.216,
#
# Epoch: 38/3000,  Iteration: 12025,  Train loss: 0.184,  Train MSE: 41.7997,  0.1s /batch.  Train Accuracy: %97.761
# Epoch: 38/3000,  Iteration: 12050,  Train loss: 0.186,  Train MSE: 44.1235,  0.1s /batch.  Train Accuracy: %97.604
# Epoch: 38/3000,  Iteration: 12075,  Train loss: 0.183,  Train MSE: 44.1697,  0.1s /batch.  Train Accuracy: %97.550
#
# Validation loss: 0.183,  Validation mse: 65.6759,  Validation accuracy: %96.084,
#
# Epoch: 38/3000,  Iteration: 12100,  Train loss: 0.181,  Train MSE: 44.0595,  0.1s /batch.  Train Accuracy: %97.567
# Epoch: 38/3000,  Iteration: 12125,  Train loss: 0.182,  Train MSE: 41.8956,  0.1s /batch.  Train Accuracy: %97.695
# Epoch: 38/3000,  Iteration: 12150,  Train loss: 0.183,  Train MSE: 45.6055,  0.1s /batch.  Train Accuracy: %97.487
#
# Validation loss: 0.183,  Validation mse: 67.0294,  Validation accuracy: %95.925,
#
# Epoch: 38/3000,  Iteration: 12175,  Train loss: 0.179,  Train MSE: 41.6368,  0.1s /batch.  Train Accuracy: %97.764
# Epoch: 39/3000,  Iteration: 12200,  Train loss: 0.182,  Train MSE: 49.6386,  0.1s /batch.  Train Accuracy: %97.084
# Epoch: 39/3000,  Iteration: 12225,  Train loss: 0.186,  Train MSE: 46.1632,  0.1s /batch.  Train Accuracy: %97.402
#
# Validation loss: 0.183,  Validation mse: 67.4315,  Validation accuracy: %95.945,
#
# Epoch: 39/3000,  Iteration: 12250,  Train loss: 0.182,  Train MSE: 42.6107,  0.1s /batch.  Train Accuracy: %97.698
# Epoch: 39/3000,  Iteration: 12275,  Train loss: 0.181,  Train MSE: 41.9452,  0.1s /batch.  Train Accuracy: %97.713
# Epoch: 39/3000,  Iteration: 12300,  Train loss: 0.183,  Train MSE: 42.5754,  0.1s /batch.  Train Accuracy: %97.684
#
# Validation loss: 0.183,  Validation mse: 65.5096,  Validation accuracy: %96.045,
#
# Epoch: 39/3000,  Iteration: 12325,  Train loss: 0.184,  Train MSE: 42.8456,  0.1s /batch.  Train Accuracy: %97.660
# Epoch: 39/3000,  Iteration: 12350,  Train loss: 0.183,  Train MSE: 45.4670,  0.1s /batch.  Train Accuracy: %97.388
# Epoch: 39/3000,  Iteration: 12375,  Train loss: 0.184,  Train MSE: 43.7334,  0.1s /batch.  Train Accuracy: %97.580
#
# Validation loss: 0.183,  Validation mse: 64.7487,  Validation accuracy: %96.076,
#
# Epoch: 39/3000,  Iteration: 12400,  Train loss: 0.181,  Train MSE: 48.0351,  0.1s /batch.  Train Accuracy: %97.277
# Epoch: 39/3000,  Iteration: 12425,  Train loss: 0.183,  Train MSE: 41.8360,  0.1s /batch.  Train Accuracy: %97.772
# Epoch: 39/3000,  Iteration: 12450,  Train loss: 0.183,  Train MSE: 48.0542,  0.1s /batch.  Train Accuracy: %97.326
#
# Validation loss: 0.183,  Validation mse: 66.9802,  Validation accuracy: %95.987,
#
# Epoch: 39/3000,  Iteration: 12475,  Train loss: 0.181,  Train MSE: 43.7185,  0.1s /batch.  Train Accuracy: %97.594
# Epoch: 39/3000,  Iteration: 12500,  Train loss: 0.178,  Train MSE: 42.0342,  0.1s /batch.  Train Accuracy: %97.675
# Epoch: 40/3000,  Iteration: 12525,  Train loss: 0.179,  Train MSE: 44.0553,  0.1s /batch.  Train Accuracy: %97.524
#
# Validation loss: 0.183,  Validation mse: 66.0566,  Validation accuracy: %95.982,
#
# Epoch: 40/3000,  Iteration: 12550,  Train loss: 0.181,  Train MSE: 47.8407,  0.1s /batch.  Train Accuracy: %97.240
# Epoch: 40/3000,  Iteration: 12575,  Train loss: 0.185,  Train MSE: 43.5597,  0.1s /batch.  Train Accuracy: %97.625
# Epoch: 40/3000,  Iteration: 12600,  Train loss: 0.184,  Train MSE: 41.6493,  0.1s /batch.  Train Accuracy: %97.797
#
# Validation loss: 0.183,  Validation mse: 65.8161,  Validation accuracy: %96.039,
#
# Epoch: 40/3000,  Iteration: 12625,  Train loss: 0.185,  Train MSE: 43.6906,  0.1s /batch.  Train Accuracy: %97.633
# Epoch: 40/3000,  Iteration: 12650,  Train loss: 0.182,  Train MSE: 42.1915,  0.1s /batch.  Train Accuracy: %97.750
# Epoch: 40/3000,  Iteration: 12675,  Train loss: 0.179,  Train MSE: 43.2641,  0.1s /batch.  Train Accuracy: %97.597
#
# Validation loss: 0.183,  Validation mse: 65.0063,  Validation accuracy: %96.072,
#
# Epoch: 40/3000,  Iteration: 12700,  Train loss: 0.181,  Train MSE: 41.6232,  0.1s /batch.  Train Accuracy: %97.723
# Epoch: 40/3000,  Iteration: 12725,  Train loss: 0.178,  Train MSE: 43.5092,  0.1s /batch.  Train Accuracy: %97.567
# Epoch: 40/3000,  Iteration: 12750,  Train loss: 0.179,  Train MSE: 39.7640,  0.1s /batch.  Train Accuracy: %97.867
#
# Validation loss: 0.183,  Validation mse: 62.9193,  Validation accuracy: %96.213,
#
# Epoch: 40/3000,  Iteration: 12775,  Train loss: 0.182,  Train MSE: 44.1597,  0.1s /batch.  Train Accuracy: %97.645
# Epoch: 40/3000,  Iteration: 12800,  Train loss: 0.182,  Train MSE: 46.2462,  0.1s /batch.  Train Accuracy: %97.463
# Epoch: 40/3000,  Iteration: 12825,  Train loss: 0.184,  Train MSE: 45.1124,  0.1s /batch.  Train Accuracy: %97.458
#
# Validation loss: 0.183,  Validation mse: 65.4128,  Validation accuracy: %96.068,
#
# Epoch: 41/3000,  Iteration: 12850,  Train loss: 0.182,  Train MSE: 46.0298,  0.1s /batch.  Train Accuracy: %97.368
# Epoch: 41/3000,  Iteration: 12875,  Train loss: 0.188,  Train MSE: 43.6353,  0.1s /batch.  Train Accuracy: %97.626
# Epoch: 41/3000,  Iteration: 12900,  Train loss: 0.184,  Train MSE: 40.6839,  0.1s /batch.  Train Accuracy: %97.847
#
# Validation loss: 0.183,  Validation mse: 65.2043,  Validation accuracy: %96.052,
#
# Epoch: 41/3000,  Iteration: 12925,  Train loss: 0.181,  Train MSE: 41.0246,  0.1s /batch.  Train Accuracy: %97.850
# Epoch: 41/3000,  Iteration: 12950,  Train loss: 0.181,  Train MSE: 40.7672,  0.1s /batch.  Train Accuracy: %97.840
# Epoch: 41/3000,  Iteration: 12975,  Train loss: 0.185,  Train MSE: 43.1799,  0.1s /batch.  Train Accuracy: %97.606
#
# Validation loss: 0.183,  Validation mse: 63.9178,  Validation accuracy: %96.141,
#
# Epoch: 41/3000,  Iteration: 13000,  Train loss: 0.185,  Train MSE: 44.4537,  0.1s /batch.  Train Accuracy: %97.558
# Epoch: 41/3000,  Iteration: 13025,  Train loss: 0.181,  Train MSE: 41.3705,  0.1s /batch.  Train Accuracy: %97.783
# Epoch: 41/3000,  Iteration: 13050,  Train loss: 0.184,  Train MSE: 41.2202,  0.1s /batch.  Train Accuracy: %97.777
#
# Validation loss: 0.183,  Validation mse: 66.6844,  Validation accuracy: %95.961,
#
# Epoch: 41/3000,  Iteration: 13075,  Train loss: 0.182,  Train MSE: 40.0892,  0.1s /batch.  Train Accuracy: %97.909
# Epoch: 41/3000,  Iteration: 13100,  Train loss: 0.184,  Train MSE: 43.2495,  0.1s /batch.  Train Accuracy: %97.622
# Epoch: 41/3000,  Iteration: 13125,  Train loss: 0.181,  Train MSE: 42.6212,  0.1s /batch.  Train Accuracy: %97.676
# Validation loss: 0.183,  Validation mse: 63.0814,  Validation accuracy: %96.219,
#
# Epoch: 41/3000,  Iteration: 13150,  Train loss: 0.187,  Train MSE: 39.6406,  0.1s /batch.  Train Accuracy: %97.876
#
#
# leraning_rate=0.0002,num_layers=3,batch_size=80 finished, saved

# %% [markdown]
# <br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Network Architecture
#
# The encoder part of the network will be a typical convolutional pyramid. Each convolutional layer will be followed by a max-pooling layer to reduce the dimensions of the layers. The decoder though might be something new to you. The decoder needs to convert from a narrow representation to a wide reconstructed image. For example, the representation could be a 4x4x8 max-pool layer. This is the output of the encoder, but also the input to the decoder. We want to get a 28x28x1 image out from the decoder so we need to work our way back up from the narrow decoder input layer. A schematic of the network is shown below.
#
# <img src='assets/convolutional_autoencoder.png' width=500px>
#
# Here our final encoder layer has size 4x4x8 = 128. The original images have size 28x28 = 784, so the encoded vector is roughly 16% the size of the original image. These are just suggested sizes for each of the layers. Feel free to change the depths and sizes, but remember our goal here is to find a small representation of the input data.
#
# ### What's going on with the decoder
#
# Okay, so the decoder has these "Upsample" layers that you might not have seen before. First off, I'll discuss a bit what these layers *aren't*. Usually, you'll see **transposed convolution** layers used to increase the width and height of the layers. They work almost exactly the same as convolutional layers, but in reverse. A stride in the input layer results in a larger stride in the transposed convolution layer. For example, if you have a 3x3 kernel, a 3x3 patch in the input layer will be reduced to one unit in a convolutional layer. Comparatively, one unit in the input layer will be expanded to a 3x3 path in a transposed convolution layer. The TensorFlow API provides us with an easy way to create the layers, [`tf.nn.conv2d_transpose`](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d_transpose).
#
# However, transposed convolution layers can lead to artifacts in the final images, such as checkerboard patterns. This is due to overlap in the kernels which can be avoided by setting the stride and kernel size equal. In [this Distill article](http://distill.pub/2016/deconv-checkerboard/) from Augustus Odena, *et al*, the authors show that these checkerboard artifacts can be avoided by resizing the layers using nearest neighbor or bilinear interpolation (upsampling) followed by a convolutional layer. In TensorFlow, this is easily done with [`tf.image.resize_images`](https://www.tensorflow.org/versions/r1.1/api_docs/python/tf/image/resize_images), followed by a convolution. Be sure to read the Distill article to get a better understanding of deconvolutional layers and why we're using upsampling.
#
# > **Exercise:** Build the network shown above. Remember that a convolutional layer with strides of 1 and 'same' padding won't reduce the height and width. That is, if the input is 28x28 and the convolution layer has stride = 1 and 'same' padding, the convolutional layer will also be 28x28. The max-pool layers are used the reduce the width and height. A stride of 2 will reduce the size by 2. Odena *et al* claim that nearest neighbor interpolation works best for the upsampling, so make sure to include that as a parameter in `tf.image.resize_images` or use [`tf.image.resize_nearest_neighbor`]( `https://www.tensorflow.org/api_docs/python/tf/image/resize_nearest_neighbor). For convolutional layers, use [`tf.layers.conv2d`](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d). For example, you would write `conv1 = tf.layers.conv2d(inputs, 32, (5,5), padding='same', activation=tf.nn.relu)` for a layer with a depth of 32, a 5x5 kernel, stride of (1,1), padding is 'same', and a ReLU activation. Similarly, for the max-pool layers, use [`tf.layers.max_pooling2d`](https://www.tensorflow.org/api_docs/python/tf/layers/max_pooling2d).

# %% [markdown]
# ## Training
#
# As before, here wi'll train the network. Instead of flattening the images though, we can pass them in as 28x28x1 arrays.

# %%
sess = tf.Session()

# %%
epochs = 20
batch_size = 200
sess.run(tf.global_variables_initializer())
for e in range(epochs):
    for ii in range(mnist.train.num_examples//batch_size):
        batch = mnist.train.next_batch(batch_size)
        imgs = batch[0].reshape((-1, 28, 28, 1))
        batch_cost, _ = sess.run([cost, opt], feed_dict={inputs_: imgs,
                                                         targets_: imgs})

        print("Epoch: {}/{}...".format(e+1, epochs),
              "Training loss: {:.4f}".format(batch_cost))

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
in_imgs = mnist.test.images[:10]
reconstructed = sess.run(decoded, feed_dict={inputs_: in_imgs.reshape((10, 28, 28, 1))})

for images, row in zip([in_imgs, reconstructed], axes):
    for img, ax in zip(images, row):
        ax.imshow(img.reshape((28, 28)), cmap='Greys_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)


fig.tight_layout(pad=0.1)

# %%
sess.close()

# %% [markdown]
# ## Denoising
#
# As I've mentioned before, autoencoders like the ones you've built so far aren't too useful in practive. However, they can be used to denoise images quite successfully just by training the network on noisy images. We can create the noisy images ourselves by adding Gaussian noise to the training images, then clipping the values to be between 0 and 1. We'll use noisy images as input and the original, clean images as targets. Here's an example of the noisy images I generated and the denoised images.
#
# ![Denoising autoencoder](assets/denoising.png)
#
#
# Since this is a harder problem for the network, we'll want to use deeper convolutional layers here, more feature maps. I suggest something like 32-32-16 for the depths of the convolutional layers in the encoder, and the same depths going backward through the decoder. Otherwise the architecture is the same as before.
#
# > **Exercise:** Build the network for the denoising autoencoder. It's the same as before, but with deeper layers. I suggest 32-32-16 for the depths, but you can play with these numbers, or add more layers.

# %%
inputs_ = tf.placeholder(tf.float32, (None, 28, 28, 1), name='inputs')
targets_ = tf.placeholder(tf.float32, (None, 28, 28, 1), name='targets')

### Encoder
conv1 = tf.layers.conv2d(inputs_, 32, (3,3), padding='same', activation=tf.nn.relu)
# Now 28x28x32
maxpool1 = tf.layers.max_pooling2d(conv1, (2,2), (2,2), padding='same')
# Now 14x14x32
conv2 = tf.layers.conv2d(maxpool1, 32, (3,3), padding='same', activation=tf.nn.relu)
# Now 14x14x32
maxpool2 = tf.layers.max_pooling2d(conv2, (2,2), (2,2), padding='same')
# Now 7x7x32
conv3 = tf.layers.conv2d(maxpool2, 16, (3,3), padding='same', activation=tf.nn.relu)
# Now 7x7x16
encoded = tf.layers.max_pooling2d(conv3, (2,2), (2,2), padding='same')
# Now 4x4x16

### Decoder
upsample1 = tf.image.resize_nearest_neighbor(encoded, (7,7))
# Now 7x7x16
conv4 = tf.layers.conv2d(upsample1, 16, (3,3), padding='same', activation=tf.nn.relu)
# Now 7x7x16
upsample2 = tf.image.resize_nearest_neighbor(conv4, (14,14))
# Now 14x14x16
conv5 = tf.layers.conv2d(upsample2, 32, (3,3), padding='same', activation=tf.nn.relu)
# Now 14x14x32
upsample3 = tf.image.resize_nearest_neighbor(conv5, (28,28))
# Now 28x28x32
conv6 = tf.layers.conv2d(upsample3, 32, (3,3), padding='same', activation=tf.nn.relu)
# Now 28x28x32

logits = tf.layers.conv2d(conv6, 1, (3,3), padding='same', activation=None)
#Now 28x28x1

decoded = tf.nn.sigmoid(logits, name='decoded')

loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=targets_, logits=logits)
cost = tf.reduce_mean(loss)
opt = tf.train.AdamOptimizer(0.001).minimize(cost)

# %%
sess = tf.Session()

# %%
epochs = 100
batch_size = 200
# Set's how much noise we're adding to the MNIST images
noise_factor = 0.5
sess.run(tf.global_variables_initializer())
for e in range(epochs):
    for ii in range(mnist.train.num_examples//batch_size):
        batch = mnist.train.next_batch(batch_size)
        # Get images from the batch
        imgs = batch[0].reshape((-1, 28, 28, 1))
        
        # Add random noise to the input images
        noisy_imgs = imgs + noise_factor * np.random.randn(*imgs.shape)
        # Clip the images to be between 0 and 1
        noisy_imgs = np.clip(noisy_imgs, 0., 1.)
        
        # Noisy images as inputs, original images as targets
        batch_cost, _ = sess.run([cost, opt], feed_dict={inputs_: noisy_imgs,
                                                         targets_: imgs})

        print("Epoch: {}/{}...".format(e+1, epochs),
              "Training loss: {:.4f}".format(batch_cost))

# %% [markdown]
# ## Checking out the performance
#
# Here I'm adding noise to the test images and passing them through the autoencoder. It does a suprising great job of removing the noise, even though it's sometimes difficult to tell what the original number is.

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
in_imgs = mnist.test.images[:10]
noisy_imgs = in_imgs + noise_factor * np.random.randn(*in_imgs.shape)
noisy_imgs = np.clip(noisy_imgs, 0., 1.)

reconstructed = sess.run(decoded, feed_dict={inputs_: noisy_imgs.reshape((10, 28, 28, 1))})

for images, row in zip([noisy_imgs, reconstructed], axes):
    for img, ax in zip(images, row):
        ax.imshow(img.reshape((28, 28)), cmap='Greys_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

fig.tight_layout(pad=0.1)
